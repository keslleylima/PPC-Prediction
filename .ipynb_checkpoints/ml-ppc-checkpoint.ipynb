# %% [markdown]
# # Importações

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
import matplotlib.pyplot as plt
# %matplotlib inline
from imblearn.under_sampling import RandomUnderSampler
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# # Leitura dataset e pré-processamento

# %%
dataset['idx'] = dataset.index

x = dataset.iloc[1:5].index
dataset['selected'] = dataset['idx'].apply(lambda idx: idx in x)
dataset[dataset['selected']]
dataset = dataset.drop('idx')
dataset = dataset.drop('selected')
# Out:
#                                                    Name  CountInput  \
# 1884  org.jfree.chart.annotations.CategoryPointerAnn...           2
# 16    org.biojava.nbio.protmod.ProteinModificationRe...           4
# 1568  com.urbanairship.api.channel.model.email.Email...           7
# 1762  org.jfree.chart.StandardChartTheme.setDomainGr...           2
#
#       CountLineCode  CountOutput  CountStmt  CountStmtDecl  CountPath  \
# 1884              4            2          3              1          1
# 16                4            3          3              1          1
# 1568              4            2          3              1          1
# 1762              4            2          3              1          1
#
#       CountPathLog  CountStmtExe  Cyclomatic  ...  CountStmt.1  \
# 1884             0             2           1  ...           49
# 16               0             2           1  ...           19
# 1568             0             2           1  ...            4
# 1762             0             2           1  ...          116
#
#       CountStmtDecl.1  CountPath.1 CountPathLog.1 CountStmtExe.1 Cyclomatic.1  \
# 1884                4            1              0             45            1
# 16                  3            1              0             16            1
# 1568                2            1              0              2            1
# 1762                3            1              0            113            1
#
#       CyclomaticStrict.1                     Project   idx  selected
# 1884                   1                  Jfreechart  1884      True
# 16                     1                     Biojava    16      True
# 1568                   1  Urban Airship Java Library  1568      True
# 1762                   1                  Jfreechart  1762      True
#
# [4 rows x 28 columns]

# %%
global dataset
global dataset_original

def load_dataset():
    global dataset
    global dataset_original
    
    dataset = pd.read_csv('dataset-unificado.csv', sep=';')
    dataset_original = dataset
    
def under_sampling():
    global dataset
    global dataset_original
    
    #rus = RandomUnderSampler(random_state=0, sampling_strategy={0:0, 1:299, 2:900, 3:826, 4:458, 5:233})
    #rus = RandomUnderSampler(random_state=0, sampling_strategy={0:0, 1:454, 2:970, 3:717, 4:458, 5:204})
    #rus = RandomUnderSampler(random_state=0, sampling_strategy={0:0, 1:454, 2:970, 3:717})
    rus = RandomUnderSampler(random_state=0, sampling_strategy={1:454})
    X_res, y_res = rus.fit_resample(
            pd.DataFrame(dataset.index.array)[0].values.reshape(-1,1), 
            dataset['Cyclomatic'].values
    )
    
    dataset['idx'] = dataset.index
    idx_selected = X_res.reshape(1,-1)[0]
    dataset['selected'] = dataset['idx'].apply(lambda idx: idx in idx_selected)
    dataset = dataset[dataset['selected']]
    dataset = dataset.drop('idx', axis=1)
    dataset = dataset.drop('selected', axis=1)
    
def remove_last_column():
    global dataset
    
    dataset = dataset.iloc[:,:-1]
    
def remove_nan():
    global dataset
    
    dataset = dataset.dropna()
    
def fix_coverage_metrics():
    global dataset
    
    dataset.iloc[:,-1] = dataset.iloc[:,-1].apply(lambda ppc: float(ppc.replace(',', '.')))
    dataset.iloc[:,-2] = dataset.iloc[:,-2].apply(lambda ec: float(ec.replace(',', '.')))
    
def remove_coverage_metrics_with_zero():
    global dataset
    
    dataset = dataset[dataset['EdgeCoverage'] > 0]
    dataset = dataset[dataset['PrimePathCoverage'] > 0]
    
def select_metrics(metrics):
    global dataset
    
    dataset = dataset[metrics]
    
def print_dataset_info():
    global dataset
    
    print('Dataset size: ', dataset.shape[0])
    print('Dataset original size: ', dataset_original.shape[0])
    print('Média complexidade dataset: ', dataset_original['Cyclomatic'].mean())
    print('Média complexidade dataset balanceado: ', dataset['Cyclomatic'].mean())
    plt.title("Complexidade do dataset após pré-processamento")
    sns.histplot(dataset['Cyclomatic'])

# %%
original_metrics = [
    # Método testado
    'Name','CountInput','CountLine','CountLineBlank','CountLineCode','CountLineCodeDecl',
    'CountLineCodeExe','CountLineComment','CountOutput','CountStmt',
    'CountStmtDecl','CountPath','CountPathLog','CountStmtExe',
    'Cyclomatic','CyclomaticModified','CyclomaticStrict','Essential',
    'Knots','MaxEssentialKnots','MaxNesting','MinEssentialKnots','EdgeCoverage','PrimePathCoverage',
    
    # Método de teste
    'Name.1','CountInput.1','CountLine.1','CountLineBlank.1','CountLineCode.1','CountLineCodeDecl.1',
    'CountLineCodeExe.1','CountLineComment.1','CountOutput.1','CountStmt.1',
    'CountStmtDecl.1','CountPath.1','CountPathLog.1','CountStmtExe.1',
    'Cyclomatic.1','CyclomaticModified.1','CyclomaticStrict.1','Essential.1',
    'Knots.1','MaxEssentialKnots.1','MaxNesting.1','MinEssentialKnots.1',
]

selected_metrics = [
    # Método testado
    'Name','CountInput','CountLineCode',
    'CountOutput','CountStmt',
    'CountStmtDecl','CountPath','CountPathLog','CountStmtExe',
    'Cyclomatic','CyclomaticStrict',
    'Knots','MaxNesting','EdgeCoverage','PrimePathCoverage',
    
    # Método de teste
    'Name.1','CountLineCode.1',
    'CountOutput.1','CountStmt.1',
    'CountStmtDecl.1','CountPath.1','CountPathLog.1','CountStmtExe.1',
    'Cyclomatic.1','CyclomaticStrict.1'
]

# %%
load_dataset()
remove_last_column()
remove_nan()
fix_coverage_metrics()
remove_coverage_metrics_with_zero()
under_sampling()
select_metrics(selected_metrics)

# %% [markdown]
# # Características do dataset

# %%
print_dataset_info()
# Out:
# Dataset size:  3558
# Dataset original size:  5342
# Média complexidade dataset:  3.3569824035941593
# Média complexidade dataset balanceado:  4.127880831928049

# %%
def signature_to_project(signature):
    project = ''
    
    if 'com.puppycrawl.tools.checkstyle' in signature:
        project = 'Checkstyle'
    elif 'exp4j' in signature:
        project = 'Exp4j'
    elif 'biojava' in signature:
        project = 'Biojava'
    elif 'org.jfree' in signature:
        project = 'Jfreechart'
    elif 'com.urbanairship' in signature:
        project = 'Urban Airship Java Library'
    elif 'org.apache.commons.text' in signature:
        project = 'Apache Commons Text'
    elif 'dubbo' in signature:
        project = 'Apache Dubbo'
    elif 'org.apache.commons.lang3' in signature:
        project = 'Apache Commons Lang'
    elif 'math3' in signature:
        project = 'Apache Commons Math'
        
    return project

d2 = dataset
d2['Project'] = dataset['Name'].apply(signature_to_project)
plt.figure(figsize=(16,5))
plt.title("Contribuição de cada projeto no dataset após pré-processamento")

contrib_projetos = d2.groupby('Project')
contrib_projetos = contrib_projetos.count()

sns.countplot(y='Project', data=d2, orient='h')
# Out:
# <AxesSubplot:title={'center':'Contribuição de cada projeto no dataset após pré-processamento'}, xlabel='count', ylabel='Project'>

# %%
plt.figure(figsize=(16,10))
plt.title('Complexidade do dataset após pré-processamento por projeto')
sns.countplot(y='Project', data=d2, orient='h', hue='Cyclomatic')
# Out:
# <AxesSubplot:title={'center':'Complexidade do dataset após pré-processamento por projeto'}, xlabel='count', ylabel='Project'>

# %%
ax = sns.jointplot(x='EdgeCoverage', y='PrimePathCoverage', data=dataset, kind='scatter', color='purple')
ax.set_axis_labels('Edge coverage', 'Prime Path Coverage')
plt.show(ax)

# %%
plt.figure(figsize=(10,7))
plt.title("Correlação das métricas após pré-processamento")
sns.heatmap(dataset.corr(), vmin=-1, vmax=1)
# Out:
# <AxesSubplot:title={'center':'Correlação das métricas após pré-processamento'}>

# %%
correlations = dataset.corr()['PrimePathCoverage']
correlations = correlations.drop('PrimePathCoverage')

metrics = correlations.index
ppc_corr = correlations.values
corr_table = pd.DataFrame(columns=['Metrics', 'Correlation'])
corr_table['Metrics'] = metrics
corr_table['Correlation'] = ppc_corr
corr_table = corr_table.sort_values(ascending=False, by='Correlation')

plt.figure(figsize=(10,8))
sns.barplot(y='Metrics', x='Correlation', data=corr_table)

display(corr_table)
# Out:
#                Metrics  Correlation
# 12        EdgeCoverage     0.745812
# 19      CountStmtExe.1     0.188720
# 15         CountStmt.1     0.173953
# 13     CountLineCode.1     0.167847
# 14       CountOutput.1     0.141191
# 18      CountPathLog.1     0.048480
# 21  CyclomaticStrict.1     0.044003
# 20        Cyclomatic.1     0.041824
# 17         CountPath.1    -0.006315
# 16     CountStmtDecl.1    -0.079818
# 0           CountInput    -0.095240
# 5            CountPath    -0.204577
# 10               Knots    -0.281437
# 4        CountStmtDecl    -0.302060
# 2          CountOutput    -0.388803
# 9     CyclomaticStrict    -0.430518
# 8           Cyclomatic    -0.458751
# 7         CountStmtExe    -0.459335
# 3            CountStmt    -0.462255
# 1        CountLineCode    -0.463940
# 11          MaxNesting    -0.498118
# 6         CountPathLog    -0.575432

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3500 entries, 0 to 5341
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                3500 non-null   object
#  1   CountInput          3500 non-null   int64
#  2   CountLineCode       3500 non-null   int64
#  3   CountOutput         3500 non-null   int64
#  4   CountStmt           3500 non-null   int64
#  5   CountStmtDecl       3500 non-null   int64
#  6   CountPath           3500 non-null   int64
#  7   CountPathLog        3500 non-null   int64
#  8   CountStmtExe        3500 non-null   int64
#  9   Cyclomatic          3500 non-null   int64
#  10  CyclomaticStrict    3500 non-null   int64
#  11  Knots               3500 non-null   int64
#  12  MaxNesting          3500 non-null   int64
#  13  EdgeCoverage        3500 non-null   float64
#  14  PrimePathCoverage   3500 non-null   float64
#  15  Name.1              3500 non-null   object
#  16  CountLineCode.1     3500 non-null   int64
#  17  CountOutput.1       3500 non-null   int64
#  18  CountStmt.1         3500 non-null   int64
#  19  CountStmtDecl.1     3500 non-null   int64
#  20  CountPath.1         3500 non-null   int64
#  21  CountPathLog.1      3500 non-null   int64
#  22  CountStmtExe.1      3500 non-null   int64
#  23  Cyclomatic.1        3500 non-null   int64
#  24  CyclomaticStrict.1  3500 non-null   int64
# dtypes: float64(2), int64(21), object(2)
# memory usage: 710.9+ KB

# %%
dataset.describe()
# Out:
#         CountInput  CountLineCode  CountOutput    CountStmt  CountStmtDecl  \
# count  3500.000000    3500.000000  3500.000000  3500.000000    3500.000000
# mean     23.820571      16.649143     5.720286    11.678286       3.138000
# std      40.822710      17.236425     5.141584    11.768071       3.690992
# min       1.000000       4.000000     1.000000     3.000000       1.000000
# 25%       5.000000       7.000000     3.000000     5.000000       1.000000
# 50%       9.000000      12.000000     4.000000     8.000000       2.000000
# 75%      22.000000      19.000000     7.000000    13.000000       3.000000
# max     201.000000     225.000000    58.000000   144.000000      49.000000
#
#          CountPath  CountPathLog  CountStmtExe   Cyclomatic  CyclomaticStrict  \
# count  3500.000000   3500.000000   3500.000000  3500.000000       3500.000000
# mean     70.813714      0.513143      8.540286     4.131143          4.710000
# std     636.485217      0.685537      9.415670     4.304859          5.238268
# min       1.000000      0.000000      1.000000     1.000000          1.000000
# 25%       2.000000      0.000000      3.000000     2.000000          2.000000
# 50%       3.000000      0.000000      6.000000     3.000000          3.000000
# 75%       6.000000      1.000000     10.000000     5.000000          5.000000
# max    6912.000000      4.000000     99.000000    50.000000         72.000000
#
#        ...  PrimePathCoverage  CountLineCode.1  CountOutput.1  CountStmt.1  \
# count  ...        3500.000000      3500.000000    3500.000000  3500.000000
# mean   ...           0.618931        20.220000       8.705714    16.285714
# std    ...           0.314311        27.253253       7.552974    23.235749
# min    ...           0.000900         3.000000       1.000000     2.000000
# 25%    ...           0.400000         8.000000       5.000000     6.000000
# 50%    ...           0.500000        14.000000       7.000000    10.000000
# 75%    ...           1.000000        21.000000      10.000000    17.000000
# max    ...           1.000000       273.000000      70.000000   230.000000
#
#        CountStmtDecl.1    CountPath.1  CountPathLog.1  CountStmtExe.1  \
# count      3500.000000    3500.000000     3500.000000     3500.000000
# mean          4.296857     153.828000        0.088857       11.988857
# std           3.101252    8862.093007        0.359958       22.729271
# min           1.000000       1.000000        0.000000        0.000000
# 25%           2.000000       1.000000        0.000000        3.000000
# 50%           3.000000       1.000000        0.000000        6.000000
# 75%           5.000000       1.000000        0.000000       12.000000
# max          32.000000  524288.000000        6.000000      226.000000
#
#        Cyclomatic.1  CyclomaticStrict.1
# count   3500.000000         3500.000000
# mean       1.414571            1.435429
# std        1.177509            1.246706
# min        1.000000            1.000000
# 25%        1.000000            1.000000
# 50%        1.000000            1.000000
# 75%        1.000000            1.000000
# max       20.000000           20.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# # Funções uteis

# %%
k = 10
metricas_erro = [
    'r2', 'max_error', 'neg_mean_absolute_error',
    'neg_mean_squared_error', 'neg_root_mean_squared_error',
    'neg_mean_squared_log_error', 'neg_median_absolute_error'
]
previsores = [
    # Método testado
    'CountInput','CountLineCode',
    'CountOutput','CountStmt',
    'CountStmtDecl','CountPath','CountPathLog','CountStmtExe',
    'Cyclomatic','CyclomaticStrict',
    'Knots','MaxNesting','EdgeCoverage',
    
    # Método de teste
    'CountLineCode.1',
    'CountOutput.1','CountStmt.1',
    'CountStmtDecl.1','CountPath.1','CountPathLog.1','CountStmtExe.1',
    'Cyclomatic.1','CyclomaticStrict.1'
]

metrics_without_ec = previsores.copy()
metrics_without_ec.remove('EdgeCoverage')

# %%
def feature_importance_of(regressor_model, previsores, ppc, previsores_nome):
    results = permutation_importance(regressor_model, previsores, ppc, scoring='neg_mean_squared_error')  
    importance = results.importances_mean

    return importance

# %%
def escalonador(dados):
    scaler = MinMaxScaler()
    #scaler = StandardScaler()
    return scaler.fit_transform(dados)

def evaluate(previsores, classificador, d = dataset, k=10, apenas_escalonamento=False, display_prediction=False, display_feature_importance=False):
    ppc = d['PrimePathCoverage'].values
    previsores_content = d[previsores].values
    
    error_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=['no_scaled', 'scaled']
    )
    

    if not apenas_escalonamento:
        resultados = cross_validate(
                classificador, 
                previsores_content, 
                ppc, 
                cv=k, 
                scoring=metricas_erro, 
                return_estimator=True
        )
        error_metrics_table['no_scaled']['Mean Abs Error'] = abs(resultados['test_neg_mean_absolute_error'].mean())
        error_metrics_table['no_scaled']['Mean Sqr Error'] = abs(resultados['test_neg_mean_squared_error'].mean())
        error_metrics_table['no_scaled']['Mean Sqr Log Error'] = abs(resultados['test_neg_mean_squared_log_error'].mean())
        error_metrics_table['no_scaled']['Mean Median Error'] = abs(resultados['test_neg_median_absolute_error'].mean())
        error_metrics_table['no_scaled']['R2 Score'] = abs(resultados['test_r2'].mean())
        
    resultados_escalonados = cross_validate(
            classificador, 
            escalonador(previsores_content), 
            ppc, 
            cv=k, 
            scoring=metricas_erro, 
            return_estimator=True
    )
    error_metrics_table['scaled']['Mean Abs Error'] = abs(resultados_escalonados['test_neg_mean_absolute_error'].mean())
    error_metrics_table['scaled']['Mean Sqr Error'] = abs(resultados_escalonados['test_neg_mean_squared_error'].mean())
    error_metrics_table['scaled']['Mean Sqr Log Error'] = abs(resultados_escalonados['test_neg_mean_squared_log_error'].mean())
    error_metrics_table['scaled']['Mean Median Error'] = abs(resultados_escalonados['test_neg_median_absolute_error'].mean())
    error_metrics_table['scaled']['R2 Score'] = abs(resultados_escalonados['test_r2'].mean())
    
    if display_prediction:
        k_current = 0
        for estimator in resultados_escalonados['estimator']:
            ppc_predict = estimator.predict(escalonador(previsores_content))
            predict_table = pd.DataFrame(index=[i for i in range(len(ppc_predict))],columns=['PPC correct', 'PPC predict', 'MAE'])

            for i in range(len(ppc_predict)):
                predict_table['PPC correct'][i] = ppc[i]
                predict_table['PPC predict'][i] = ppc_predict[i]
                predict_table['MAE'][i] = abs(ppc[i] - ppc_predict[i])
                #print(ppc_predict[i], ppc[i])
            print('k:', k_current)
            display(predict_table)
            k_current += 1
    
    if display_feature_importance:
        k_current = 0
        columns = [i for i in range(k)]
        columns.append('Mean')
        fi_scaled_table = pd.DataFrame(columns=columns, index=d[previsores].columns)
        
        for estimator in resultados_escalonados['estimator']:
            fi_scaled_table[k_current] = feature_importance_of(
                estimator, escalonador(previsores_content), ppc, d[previsores].columns
            )
            k_current += 1
            
        for i in range(fi_scaled_table.shape[0]):
            fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
        

        fi_final = pd.DataFrame(columns=['Metrics', 'Importance'])
        fi_final['Metrics'] = fi_scaled_table.index.values
        fi_final['Importance'] = fi_scaled_table['Mean'].values

        fi_final = fi_final.sort_values(ascending=False, by='Importance')
        display(fi_final)
        plt.figure(figsize=(12,8))
        plt.title("Feature importance - K = " + str(k) + " - Mean")
        plt.axis([0, fi_final['Importance'].values.max(), 0, len(fi_final.index.values)])
        sns.barplot(y=fi_final['Metrics'].values, x=fi_final['Importance'].values, orient='h')
        plt.show()

    
    return error_metrics_table

# %%
def feature_importance(classificador, d = dataset, prev = previsores):
    ppc = d['PrimePathCoverage'].values
    importance_dataset = pd.DataFrame(
            [0]*len(prev),
            index=prev,
            columns=['importance']
    )
    previsores_content = d[prev].values
    resultados = cross_validate(
            classificador, 
            previsores_content, 
            ppc, 
            cv=k, 
            scoring=metricas_erro,
            return_estimator=True
    )
    resultados_escalonados = cross_validate(
            classificador, 
            escalonador(previsores_content), 
            ppc, 
            cv=k, 
            scoring=metricas_erro,
            return_estimator=True
    )
    
    print('-----< SEM ESCALONAMENTO >-----')
    #print(resultados)
    for idx,estimator in enumerate(resultados['estimator']):
        feature_importances = pd.DataFrame(estimator.feature_importances_,
                                           index=prev,
                                           columns=['importance'])
        importance_dataset += feature_importances
 
    #print(importance_dataset) 
    importance_dataset['mean'] = importance_dataset['importance'] / k
    plt.figure(figsize=(10,9))
    plt.title("Feature importance - Random forest - K = 10 - Mean")
    plt.barh(prev, importance_dataset['mean'].values)
    plt.show()
    
    importance_dataset = pd.DataFrame(
            [0]*len(prev),
            index=prev,
            columns=['importance']
    )
    print('\n')
    
    print('-----< COM ESCALONAMENTO >-----')
    for idx,estimator in enumerate(resultados_escalonados['estimator']):
        feature_importances = pd.DataFrame(estimator.feature_importances_,
                                           index=prev,
                                           columns=['importance'])
        importance_dataset += feature_importances

    importance_dataset['mean'] = importance_dataset['importance'] / k
    print(importance_dataset['mean'].sort_values(ascending=False))
    plt.figure(figsize=(10,9))
    plt.title("Feature importance - Random forest - K = 10 - Mean")
    plt.barh(prev, importance_dataset['mean'].values)
    plt.show()

# %%
def estimator_metrics_to_dataframe(estimator_results, dataframe):
    dataframe['Mean']['Mean Abs Error'] = estimator_results.iloc[0,:-1].mean()
    dataframe['Mean']['Mean Sqr Error'] = estimator_results.iloc[1,:-1].mean()
    dataframe['Mean']['Mean Sqr Log Error'] = estimator_results.iloc[2,:-1].mean()
    dataframe['Mean']['Mean Median Error'] = estimator_results.iloc[3,:-1].mean()
    dataframe['Mean']['R2 Score'] = estimator_results.iloc[4,:-1].mean()

# %% [markdown]
# # Experimentos

# %% [markdown]
# ## Linear Regression

# %%
evaluate(previsores, LinearRegression(positive=True), display_feature_importance=True)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 12        EdgeCoverage     0.107628
# 19      CountStmtExe.1   0.00134039
# 17         CountPath.1  0.000177275
# 18      CountPathLog.1     7.35e-06
# 14       CountOutput.1  4.06533e-06
# 20        Cyclomatic.1  2.98571e-06
# 0           CountInput -6.93889e-19
# 1        CountLineCode -6.93889e-19
# 16     CountStmtDecl.1 -6.93889e-19
# 15         CountStmt.1 -6.93889e-19
# 13     CountLineCode.1 -6.93889e-19
# 11          MaxNesting -6.93889e-19
# 10               Knots -6.93889e-19
# 9     CyclomaticStrict -6.93889e-19
# 8           Cyclomatic -6.93889e-19
# 7         CountStmtExe -6.93889e-19
# 6         CountPathLog -6.93889e-19
# 5            CountPath -6.93889e-19
# 4        CountStmtDecl -6.93889e-19
# 3            CountStmt -6.93889e-19
# 2          CountOutput -6.93889e-19
# 21  CyclomaticStrict.1 -1.36874e-07
#                    no_scaled scaled
# Mean Abs Error           NaN    NaN
# Mean Sqr Error           NaN    NaN
# Mean Sqr Log Error       NaN    NaN
# Mean Median Error        NaN    NaN
# R2 Score                 NaN    NaN

# %%
evaluate(metrics_without_ec, LinearRegression(positive=True), display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 18      CountStmtExe.1   0.00691926
# 17      CountPathLog.1  8.04184e-05
# 20  CyclomaticStrict.1  4.58711e-05
# 1        CountLineCode            0
# 19        Cyclomatic.1            0
# 16         CountPath.1            0
# 15     CountStmtDecl.1            0
# 14         CountStmt.1            0
# 12     CountLineCode.1            0
# 11          MaxNesting            0
# 0           CountInput            0
# 9     CyclomaticStrict            0
# 8           Cyclomatic            0
# 7         CountStmtExe            0
# 6         CountPathLog            0
# 5            CountPath            0
# 4        CountStmtDecl            0
# 3            CountStmt            0
# 2          CountOutput            0
# 10               Knots            0
# 13       CountOutput.1 -5.79885e-07
#                     no_scaled     scaled
# Mean Abs Error       0.269698   0.269698
# Mean Sqr Error      0.0972508  0.0972508
# Mean Sqr Log Error   0.040861   0.040861
# Mean Median Error    0.279314   0.279314
# R2 Score            0.0582428  0.0582428

# %% [markdown]
# ### Com EC

# %%
error_metrics_table = pd.DataFrame(
    index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
    columns=previsores
)

for previsor in previsores:
    print('PREVISOR ', previsor)
    metrics = evaluate([
        previsor
    ], LinearRegression(positive=True), dataset)
    error_metrics_table[previsor] = metrics['scaled']
    display(metrics)
    print('\n')
# Out:
# PREVISOR  CountInput
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountLineCode
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountOutput
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountStmt
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountStmtDecl
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountPath
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountPathLog
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountStmtExe
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  Cyclomatic
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CyclomaticStrict
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  Knots
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  MaxNesting
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  EdgeCoverage
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
#                    no_scaled scaled
# Mean Abs Error           NaN    NaN
# Mean Sqr Error           NaN    NaN
# Mean Sqr Log Error       NaN    NaN
# Mean Median Error        NaN    NaN
# R2 Score                 NaN    NaN
# PREVISOR  CountLineCode.1
#                     no_scaled     scaled
# Mean Abs Error       0.270557   0.270557
# Mean Sqr Error      0.0978687  0.0978687
# Mean Sqr Log Error  0.0411581  0.0411581
# Mean Median Error    0.283937   0.283937
# R2 Score            0.0646948  0.0646948
# PREVISOR  CountOutput.1
#                     no_scaled     scaled
# Mean Abs Error        0.27286    0.27286
# Mean Sqr Error      0.0988587  0.0988587
# Mean Sqr Log Error  0.0415958  0.0415958
# Mean Median Error    0.282403   0.282403
# R2 Score             0.072559   0.072559
# PREVISOR  CountStmt.1
#                     no_scaled     scaled
# Mean Abs Error       0.270443   0.270443
# Mean Sqr Error      0.0976113  0.0976113
# Mean Sqr Log Error  0.0410444  0.0410444
# Mean Median Error    0.282243   0.282243
# R2 Score            0.0610304  0.0610304
# PREVISOR  CountStmtDecl.1
#                     no_scaled     scaled
# Mean Abs Error       0.276394   0.276394
# Mean Sqr Error       0.100076   0.100076
# Mean Sqr Log Error  0.0420618  0.0420618
# Mean Median Error    0.299619   0.299619
# R2 Score            0.0779443  0.0779443
# PREVISOR  CountPath.1
#                     no_scaled     scaled
# Mean Abs Error       0.292224   0.292224
# Mean Sqr Error       0.983728   0.983728
# Mean Sqr Log Error  0.0458381  0.0458381
# Mean Median Error    0.299643   0.299643
# R2 Score              11.6566    11.6566
# PREVISOR  CountPathLog.1
#                     no_scaled     scaled
# Mean Abs Error       0.276094   0.276094
# Mean Sqr Error       0.099905   0.099905
# Mean Sqr Log Error  0.0419812  0.0419812
# Mean Median Error    0.298647   0.298647
# R2 Score            0.0768432  0.0768432
# PREVISOR  CountStmtExe.1
#                     no_scaled     scaled
# Mean Abs Error         0.2696     0.2696
# Mean Sqr Error      0.0971154  0.0971154
# Mean Sqr Log Error  0.0408078  0.0408078
# Mean Median Error     0.28049    0.28049
# R2 Score            0.0559094  0.0559094
# PREVISOR  Cyclomatic.1
#                     no_scaled     scaled
# Mean Abs Error       0.276268   0.276268
# Mean Sqr Error      0.0999744  0.0999744
# Mean Sqr Log Error    0.04201    0.04201
# Mean Median Error    0.298091   0.298091
# R2 Score            0.0776364  0.0776364
# PREVISOR  CyclomaticStrict.1
#                     no_scaled     scaled
# Mean Abs Error       0.276207   0.276207
# Mean Sqr Error      0.0999521  0.0999521
# Mean Sqr Log Error  0.0419981  0.0419981
# Mean Median Error    0.297808   0.297808
# R2 Score            0.0773972  0.0773972

# %%
error_metrics = error_metrics_table.iloc[-1,:].dropna()
error_metrics = error_metrics[error_metrics < 1]
y_axis = error_metrics.values
x_axis = error_metrics.index.values
plt.figure(figsize=(12,10))
plt.title('Linear Regression - R2 Score')
sns.barplot(y_axis, x_axis)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Linear Regression - R2 Score'}>

# %%
error_metrics = error_metrics_table.iloc[1,:].dropna()
error_metrics = error_metrics[error_metrics < 1]
y_axis = error_metrics.values
x_axis = error_metrics.index.values
plt.figure(figsize=(12,8))
plt.axis([0, 1, 0, len(x_axis)])
plt.title('Linear Regression - MSE')
sns.barplot(y_axis, x_axis)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Linear Regression - MSE'}>

# %%
evaluate([
    'EdgeCoverage'
], LinearRegression(fit_intercept=False), dataset)
# Out:
#                     no_scaled     scaled
# Mean Abs Error       0.184901   0.182533
# Mean Sqr Error      0.0483448  0.0473119
# Mean Sqr Log Error  0.0218347  0.0214581
# Mean Median Error     0.20299   0.196884
# R2 Score             0.481165   0.491491

# %%
evaluate([
    'MaxNesting'
], LinearRegression(fit_intercept=False), dataset)
# Out:
#                    no_scaled    scaled
# Mean Abs Error      0.453032  0.453032
# Mean Sqr Error      0.323394  0.323394
# Mean Sqr Log Error  0.146559  0.146559
# Mean Median Error   0.327277  0.327277
# R2 Score             2.60202   2.60202

# %% [markdown]
# ### Sem EC

# %% [markdown]
# ## SVR

# %%
def evaluate_svr(metrics, epsilon = 0.1, tot_seeds=0, display_feature_importance=False):
    error_scaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=[0, 'Mean']
    )
    
    error_scaled_metrics_table.index.name = 'Error metrics'
    error_scaled_metrics_table.columns.name = 'Seed'

    error_metrics = evaluate(metrics, SVR(epsilon=epsilon), dataset, apenas_escalonamento=True, display_feature_importance=display_feature_importance)
    error_scaled_metrics_table[0] = error_metrics['scaled']
    estimator_metrics_to_dataframe(error_metrics, error_scaled_metrics_table)

    print('-----< COM ESCALONAMENTO >-----')
    display(error_scaled_metrics_table)

# %%
evaluate_svr(previsores, epsilon=0.3, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 12        EdgeCoverage    0.0520167
# 6         CountPathLog    0.0115136
# 11          MaxNesting   0.00539964
# 8           Cyclomatic   0.00308153
# 9     CyclomaticStrict   0.00286708
# 4        CountStmtDecl   0.00225903
# 2          CountOutput    0.0021485
# 0           CountInput   0.00155627
# 3            CountStmt   0.00122484
# 14       CountOutput.1   0.00100807
# 7         CountStmtExe   0.00100767
# 19      CountStmtExe.1  0.000950344
# 15         CountStmt.1   0.00094115
# 13     CountLineCode.1  0.000725265
# 16     CountStmtDecl.1  0.000326493
# 10               Knots  0.000291135
# 21  CyclomaticStrict.1  0.000233551
# 20        Cyclomatic.1  0.000222892
# 18      CountPathLog.1  9.81894e-05
# 5            CountPath  4.01979e-05
# 17         CountPath.1  1.27829e-05
# 1        CountLineCode -0.000369847
# -----< COM ESCALONAMENTO >-----
# Seed                        0 Mean
# Error metrics
# Mean Abs Error       0.154718  NaN
# Mean Sqr Error      0.0321389  NaN
# Mean Sqr Log Error  0.0138712  NaN
# Mean Median Error    0.147738  NaN
# R2 Score              0.64947  NaN

# %%
evaluate_svr(metrics_without_ec, epsilon=0.3, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 6         CountPathLog    0.0156996
# 8           Cyclomatic    0.0146687
# 11          MaxNesting    0.0101882
# 7         CountStmtExe    0.0067213
# 10               Knots   0.00596422
# 18      CountStmtExe.1   0.00400424
# 14         CountStmt.1   0.00396741
# 13       CountOutput.1   0.00345277
# 0           CountInput    0.0032576
# 2          CountOutput   0.00290293
# 3            CountStmt   0.00281699
# 12     CountLineCode.1   0.00278287
# 4        CountStmtDecl   0.00255496
# 15     CountStmtDecl.1   0.00216204
# 20  CyclomaticStrict.1   0.00204789
# 1        CountLineCode   0.00197213
# 5            CountPath   0.00130847
# 19        Cyclomatic.1  0.000929841
# 17      CountPathLog.1  0.000703249
# 9     CyclomaticStrict  0.000617161
# 16         CountPath.1   2.0684e-05
# -----< COM ESCALONAMENTO >-----
# Seed                        0 Mean
# Error metrics
# Mean Abs Error       0.213967  NaN
# Mean Sqr Error      0.0586485  NaN
# Mean Sqr Log Error  0.0243966  NaN
# Mean Median Error    0.223358  NaN
# R2 Score              0.35091  NaN

# %% [markdown]
# ### Com EC

# %%
evaluate_svr([
    'CountOutput',
    'EdgeCoverage',
    'Knots',
    'CountStmtDecl',
], epsilon=0.3)
# Out:
# -----< COM ESCALONAMENTO >-----
# Seed                        0 Mean
# Error metrics
# Mean Abs Error       0.161028  NaN
# Mean Sqr Error      0.0341209  NaN
# Mean Sqr Log Error  0.0142557  NaN
# Mean Median Error    0.168555  NaN
# R2 Score              0.62534  NaN

# %%
evaluate_svr([
    'Cyclomatic', 
    'CyclomaticStrict', 
    'CountInput', 
    'CountOutput',
    'EdgeCoverage',
    'CountStmtExe.1'
], epsilon=0.4)
# Out:
# -----< COM ESCALONAMENTO >-----
#                             0 Mean
# Mean Abs Error       0.199989  NaN
# Mean Sqr Error      0.0523896  NaN
# Mean Sqr Log Error  0.0210079  NaN
# Mean Median Error    0.207589  NaN
# R2 Score              0.42035  NaN

# %%
evaluate_svr([
    'MaxNesting', 
    'CountPath', 
    'CountStmtExe', 
    'CountInput', 
    'CountOutput',
    'CountStmtExe.1'
], epsilon=0.3)
# Out:
# -----< COM ESCALONAMENTO >-----
#                             0 Mean
# Mean Abs Error       0.219906  NaN
# Mean Sqr Error      0.0618964  NaN
# Mean Sqr Log Error  0.0258661  NaN
# Mean Median Error    0.215918  NaN
# R2 Score             0.317614  NaN

# %%
evaluate_svr([
    'CountInput','CountOutput','CountPath','CountStmt','CountStmtDecl','Knots',
    'MaxNesting',
    
    'CountOutput.1','CountStmtDecl.1','CountStmtExe.1'
], epsilon=0.4)
# Out:
# -----< COM ESCALONAMENTO >-----
#                             0 Mean
# Mean Abs Error       0.241878  NaN
# Mean Sqr Error       0.076074  NaN
# Mean Sqr Log Error  0.0314353  NaN
# Mean Median Error     0.27176  NaN
# R2 Score             0.173727  NaN

# %%
evaluate_svr([
    'Cyclomatic', 
    'CountOutput',
    'EdgeCoverage'
], epsilon=0.4)
# Out:
# -----< COM ESCALONAMENTO >-----
#                             0 Mean
# Mean Abs Error        0.20216  NaN
# Mean Sqr Error      0.0538348  NaN
# Mean Sqr Log Error  0.0216835  NaN
# Mean Median Error    0.219134  NaN
# R2 Score             0.408832  NaN

# %% [markdown]
# ### Sem EC

# %% [markdown]
# ## Neural network

# %%
def evaluate_neural_network(metrics, tot_seeds=0, display_feature_importance=False):
    seeds = [i for i in range(tot_seeds+1)]
    seeds.append('Mean')
    error_scaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_scaled_metrics_table.columns.name = 'Seed'
    error_scaled_metrics_table.index.name = 'Error Metrics'

    for i in range(0,tot_seeds+1):
        error_metrics = evaluate(metrics, MLPRegressor(epsilon=0.3, random_state=i), dataset, apenas_escalonamento=True, display_feature_importance=display_feature_importance)
        error_scaled_metrics_table[i] = error_metrics['scaled']

    estimator_metrics_to_dataframe(error_scaled_metrics_table, error_scaled_metrics_table)
    
    print('-----< COM ESCALONAMENTO >-----')
    display(error_scaled_metrics_table)

# %%
evaluate_neural_network(previsores, display_feature_importance=True)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:696: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 687, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 87, in __call__
#     score = scorer._score(cached_call, estimator,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 242, in _score
#     return self._sign * self._score_func(y_true, y_pred,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\metrics\_regression.py", line 413, in mean_squared_log_error
#     raise ValueError("Mean Squared Logarithmic Error cannot be used when "
# ValueError: Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 12        EdgeCoverage    0.0459595
# 6         CountPathLog   0.00610746
# 11          MaxNesting   0.00535441
# 7         CountStmtExe   0.00245489
# 3            CountStmt   0.00172743
# 19      CountStmtExe.1   0.00119399
# 4        CountStmtDecl   0.00112413
# 1        CountLineCode  0.000745261
# 10               Knots  0.000694508
# 13     CountLineCode.1  0.000622583
# 9     CyclomaticStrict  0.000501592
# 5            CountPath  0.000442627
# 0           CountInput  0.000384335
# 18      CountPathLog.1  0.000110669
# 20        Cyclomatic.1  6.73543e-05
# 17         CountPath.1    3.177e-08
# 21  CyclomaticStrict.1 -2.13388e-05
# 14       CountOutput.1 -8.99537e-05
# 8           Cyclomatic -0.000196797
# 16     CountStmtDecl.1 -0.000312362
# 15         CountStmt.1 -0.000668055
# 2          CountOutput -0.000757691
# -----< COM ESCALONAMENTO >-----
# Seed                  0 Mean
# Error Metrics
# Mean Abs Error      NaN  NaN
# Mean Sqr Error      NaN  NaN
# Mean Sqr Log Error  NaN  NaN
# Mean Median Error   NaN  NaN
# R2 Score            NaN  NaN

# %%
evaluate_neural_network(metrics_without_ec, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 6         CountPathLog   0.00959885
# 11          MaxNesting   0.00954307
# 7         CountStmtExe   0.00203238
# 9     CyclomaticStrict   0.00117989
# 3            CountStmt   0.00111742
# 10               Knots  0.000860946
# 14         CountStmt.1  0.000810596
# 12     CountLineCode.1   0.00079661
# 2          CountOutput  0.000744278
# 1        CountLineCode  0.000625176
# 19        Cyclomatic.1  0.000371711
# 5            CountPath  0.000244302
# 18      CountStmtExe.1  0.000213346
# 0           CountInput  0.000187119
# 20  CyclomaticStrict.1  5.41148e-05
# 16         CountPath.1  3.81512e-05
# 17      CountPathLog.1  3.41877e-05
# 13       CountOutput.1  1.23674e-05
# 4        CountStmtDecl -0.000164023
# 15     CountStmtDecl.1 -0.000857021
# 8           Cyclomatic  -0.00161626
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.245779   0.245779
# Mean Sqr Error      0.0769548  0.0769548
# Mean Sqr Log Error  0.0323199  0.0323199
# Mean Median Error    0.269577   0.269577
# R2 Score             0.163131   0.163131

# %% [markdown]
# ### Com EC

# %%
evaluate_neural_network([
    'Cyclomatic', 
    'CountOutput',
    'EdgeCoverage'
])
# Out:
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.188901   0.188901
# Mean Sqr Error      0.0481586  0.0481586
# Mean Sqr Log Error  0.0212722  0.0212722
# Mean Median Error     0.20922    0.20922
# R2 Score             0.482741   0.482741

# %%
evaluate_neural_network([
    'CountInput','CountOutput','CountPath','CountStmt','CountStmtDecl','Knots',
    'MaxNesting',
    
    'CountOutput.1','CountStmtDecl.1','CountStmtExe.1'
])
# Out:
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.278923   0.278923
# Mean Sqr Error       0.103342   0.103342
# Mean Sqr Log Error  0.0431805  0.0431805
# Mean Median Error    0.298641   0.298641
# R2 Score             0.109304   0.109304

# %%
evaluate_neural_network([
    'MaxNesting', 
    'CountPath', 
    'CountStmtExe', 
    'CountInput', 
    'CountOutput',
    'CountStmtExe.1'
])
# Out:
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.268129   0.268129
# Mean Sqr Error      0.0966937  0.0966937
# Mean Sqr Log Error  0.0405922  0.0405922
# Mean Median Error    0.285464   0.285464
# R2 Score            0.0456365  0.0456365

# %%
evaluate_neural_network([
    'Cyclomatic',  
    'CyclomaticStrict', 
    'CountInput', 
    'CountOutput',
    'EdgeCoverage',
    'CountStmtExe.1'
])
# Out:
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.210638   0.210638
# Mean Sqr Error      0.0622161  0.0622161
# Mean Sqr Log Error  0.0273242  0.0273242
# Mean Median Error    0.223156   0.223156
# R2 Score             0.332297   0.332297

# %%
evaluate_neural_network([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1', 'EdgeCoverage'
])
# Out:
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.204332   0.204332
# Mean Sqr Error      0.0586719  0.0586719
# Mean Sqr Log Error  0.0256912  0.0256912
# Mean Median Error    0.218288   0.218288
# R2 Score             0.371624   0.371624

# %% [markdown]
# ### Sem EC

# %% [markdown]
# ## Random forest

# %%
def evaluate_random_forest(metrics, tot_seeds=0, display_prediction=False, display_feature_importance=False):
    seeds = [i for i in range(tot_seeds+1)]
    seeds.append('Mean')
    error_noscaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_scaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_noscaled_metrics_table.columns.name = 'Seed'
    error_noscaled_metrics_table.index.name = 'Error Metrics'
    error_scaled_metrics_table.columns.name = 'Seed'
    error_scaled_metrics_table.index.name = 'Error Metrics'

    for i in range(0,tot_seeds+1):
        error_metrics = evaluate(metrics, RandomForestRegressor(random_state=i), dataset, display_prediction=display_prediction, display_feature_importance=display_feature_importance)
        error_noscaled_metrics_table[i] = error_metrics['no_scaled']
        error_scaled_metrics_table[i] = error_metrics['scaled']

    estimator_metrics_to_dataframe(error_noscaled_metrics_table, error_noscaled_metrics_table)
    estimator_metrics_to_dataframe(error_scaled_metrics_table, error_scaled_metrics_table)
    
    print('-----< SEM ESCALONAMENTO >-----')
    display(error_noscaled_metrics_table)
    print('-----< COM ESCALONAMENTO >-----')
    display(error_scaled_metrics_table)

# %%
evaluate_random_forest(previsores, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 12        EdgeCoverage     0.118422
# 3            CountStmt   0.00949485
# 5            CountPath   0.00743927
# 2          CountOutput   0.00500247
# 10               Knots   0.00443297
# 4        CountStmtDecl   0.00351117
# 11          MaxNesting   0.00163846
# 1        CountLineCode   0.00148062
# 0           CountInput   0.00126222
# 7         CountStmtExe  0.000905927
# 14       CountOutput.1  0.000594548
# 9     CyclomaticStrict  0.000463549
# 8           Cyclomatic    0.0004349
# 16     CountStmtDecl.1  0.000416871
# 13     CountLineCode.1  0.000306826
# 19      CountStmtExe.1  0.000274663
# 6         CountPathLog  0.000272095
# 15         CountStmt.1  0.000219161
# 17         CountPath.1  7.24284e-05
# 21  CyclomaticStrict.1  6.92919e-05
# 20        Cyclomatic.1  4.40283e-05
# 18      CountPathLog.1  2.15702e-05
# -----< SEM ESCALONAMENTO >-----
# Seed                         0        Mean
# Error Metrics
# Mean Abs Error       0.0666995   0.0666995
# Mean Sqr Error       0.0150588   0.0150588
# Mean Sqr Log Error  0.00670794  0.00670794
# Mean Median Error    0.0208225   0.0208225
# R2 Score              0.829387    0.829387
# -----< COM ESCALONAMENTO >-----
# Seed                         0        Mean
# Error Metrics
# Mean Abs Error       0.0664652   0.0664652
# Mean Sqr Error       0.0150819   0.0150819
# Mean Sqr Log Error  0.00672002  0.00672002
# Mean Median Error    0.0199441   0.0199441
# R2 Score              0.829232    0.829232

# %%
evaluate_random_forest(metrics_without_ec, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 5            CountPath    0.0730515
# 1        CountLineCode    0.0133557
# 0           CountInput    0.0121735
# 18      CountStmtExe.1     0.011961
# 13       CountOutput.1   0.00926472
# 15     CountStmtDecl.1   0.00794046
# 3            CountStmt   0.00597328
# 2          CountOutput   0.00565028
# 14         CountStmt.1    0.0045471
# 12     CountLineCode.1   0.00443918
# 8           Cyclomatic   0.00409791
# 9     CyclomaticStrict    0.0031854
# 4        CountStmtDecl   0.00304719
# 11          MaxNesting    0.0029532
# 10               Knots   0.00285598
# 7         CountStmtExe   0.00253677
# 20  CyclomaticStrict.1   0.00130429
# 6         CountPathLog  0.000526731
# 16         CountPath.1  0.000455906
# 19        Cyclomatic.1   0.00040924
# 17      CountPathLog.1  8.98898e-05
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.159239   0.159239
# Mean Sqr Error      0.0459528  0.0459528
# Mean Sqr Log Error   0.018893   0.018893
# Mean Median Error    0.140998   0.140998
# R2 Score             0.465456   0.465456
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.159299   0.159299
# Mean Sqr Error      0.0460097  0.0460097
# Mean Sqr Log Error  0.0189208  0.0189208
# Mean Median Error    0.141854   0.141854
# R2 Score             0.464974   0.464974

# %%
feature_importance(RandomForestRegressor(),dataset)
# Out:
# -----< SEM ESCALONAMENTO >-----
# -----< COM ESCALONAMENTO >-----
# EdgeCoverage          0.734187
# CountStmt             0.056582
# CountPath             0.044787
# CountOutput           0.030710
# CountStmtDecl         0.019956
# Knots                 0.016666
# CountLineCode         0.013613
# CountInput            0.012075
# MaxNesting            0.009934
# CountStmtExe          0.009764
# CountPathLog          0.009465
# Cyclomatic            0.008129
# CountOutput.1         0.006594
# CyclomaticStrict      0.006540
# CountStmtDecl.1       0.004917
# CountLineCode.1       0.004360
# CountStmtExe.1        0.003945
# CountStmt.1           0.003505
# CountPath.1           0.001620
# CyclomaticStrict.1    0.001240
# Cyclomatic.1          0.000914
# CountPathLog.1        0.000496
# Name: mean, dtype: float64

# %% [markdown]
# ### Com EC

# %%
feature_importance(RandomForestRegressor())
# Out:
# -----< SEM ESCALONAMENTO >-----
# -----< COM ESCALONAMENTO >-----
# EdgeCoverage          0.734067
# CountStmt             0.056198
# CountPath             0.047721
# CountOutput           0.031147
# CountStmtDecl         0.021369
# Knots                 0.016565
# CountLineCode         0.013270
# CountInput            0.011597
# MaxNesting            0.010216
# CountStmtExe          0.009792
# CountPathLog          0.008762
# CountOutput.1         0.006748
# CyclomaticStrict      0.006133
# Cyclomatic            0.005333
# CountStmtDecl.1       0.004805
# CountLineCode.1       0.004305
# CountStmtExe.1        0.004130
# CountStmt.1           0.003518
# CountPath.1           0.001554
# CyclomaticStrict.1    0.001307
# Cyclomatic.1          0.000936
# CountPathLog.1        0.000524
# Name: mean, dtype: float64

# %%
evaluate_random_forest([
    'CountOutput',
    'EdgeCoverage',
    'Knots',
    'CountStmtDecl'
], display_prediction=True)
# Out:
# k: 0
#      PPC correct PPC predict        MAE
# 0            0.8    0.782527  0.0174732
# 1         0.7143    0.782527  0.0682268
# 2            0.7    0.917276   0.217276
# 3              1    0.955123  0.0448767
# 4         0.4528    0.414424  0.0383755
# ...          ...         ...        ...
# 3495           1    0.989887  0.0101131
# 3496           1           1          0
# 3497           1    0.989887  0.0101131
# 3498           1           1          0
# 3499         0.5         0.5          0
#
# [3500 rows x 3 columns]
# k: 1
#      PPC correct PPC predict          MAE
# 0            0.8    0.800692  0.000692271
# 1         0.7143    0.800692    0.0863923
# 2            0.7    0.846379     0.146379
# 3              1    0.957117    0.0428835
# 4         0.4528    0.449912     0.002888
# ...          ...         ...          ...
# 3495           1    0.993054   0.00694583
# 3496           1           1            0
# 3497           1    0.993054   0.00694583
# 3498           1           1            0
# 3499         0.5         0.5            0
#
# [3500 rows x 3 columns]
# k: 2
#      PPC correct PPC predict          MAE
# 0            0.8    0.800692  0.000692271
# 1         0.7143    0.800692    0.0863923
# 2            0.7    0.843507     0.143507
# 3              1    0.961543    0.0384575
# 4         0.4528     0.44983      0.00297
# ...          ...         ...          ...
# 3495           1           1            0
# 3496           1           1            0
# 3497           1           1            0
# 3498           1           1            0
# 3499         0.5         0.5            0
#
# [3500 rows x 3 columns]
# k: 3
#      PPC correct PPC predict         MAE
# 0            0.8    0.794868  0.00513166
# 1         0.7143    0.794868   0.0805683
# 2            0.7      0.8478      0.1478
# 3              1    0.957144   0.0428562
# 4         0.4528    0.454141    0.001341
# ...          ...         ...         ...
# 3495           1    0.993499   0.0065013
# 3496           1           1           0
# 3497           1    0.993499   0.0065013
# 3498           1           1           0
# 3499         0.5         0.5           0
#
# [3500 rows x 3 columns]
# k: 4
#      PPC correct PPC predict         MAE
# 0            0.8    0.802099  0.00209924
# 1         0.7143    0.802099   0.0877992
# 2            0.7    0.851924    0.151924
# 3              1    0.951557   0.0484427
# 4         0.4528    0.441934    0.010866
# ...          ...         ...         ...
# 3495           1    0.991832   0.0081683
# 3496           1           1           0
# 3497           1    0.991832   0.0081683
# 3498           1           1           0
# 3499         0.5         0.5           0
#
# [3500 rows x 3 columns]
# k: 5
#      PPC correct PPC predict         MAE
# 0            0.8    0.804099  0.00409924
# 1         0.7143    0.804099   0.0897992
# 2            0.7    0.844802    0.144802
# 3              1    0.963169   0.0368311
# 4         0.4528    0.447944    0.004856
# ...          ...         ...         ...
# 3495           1    0.997638  0.00236158
# 3496           1           1           0
# 3497           1    0.997638  0.00236158
# 3498           1           1           0
# 3499         0.5         0.5           0
#
# [3500 rows x 3 columns]
# k: 6
#      PPC correct PPC predict         MAE
# 0            0.8    0.804099  0.00409924
# 1         0.7143    0.804099   0.0897992
# 2            0.7    0.843784    0.143784
# 3              1     0.96069   0.0393105
# 4         0.4528    0.450261    0.002539
# ...          ...         ...         ...
# 3495           1    0.994166   0.0058345
# 3496           1           1           0
# 3497           1    0.994166   0.0058345
# 3498           1           1           0
# 3499         0.5         0.5           0
#
# [3500 rows x 3 columns]
# k: 7
#      PPC correct PPC predict         MAE
# 0            0.8    0.804099  0.00409924
# 1         0.7143    0.804099   0.0897992
# 2            0.7     0.84756     0.14756
# 3              1     0.96267     0.03733
# 4         0.4528    0.448727    0.004073
# ...          ...         ...         ...
# 3495           1    0.988498   0.0115023
# 3496           1           1           0
# 3497           1    0.988498   0.0115023
# 3498           1           1           0
# 3499         0.5         0.5           0
#
# [3500 rows x 3 columns]
# k: 8
#      PPC correct PPC predict         MAE
# 0            0.8    0.802099  0.00209924
# 1         0.7143    0.802099   0.0877992
# 2            0.7    0.852407    0.152407
# 3              1    0.961716   0.0382841
# 4         0.4528    0.451758    0.001042
# ...          ...         ...         ...
# 3495           1    0.991832   0.0081683
# 3496           1           1           0
# 3497           1    0.991832   0.0081683
# 3498           1           1           0
# 3499         0.5         0.5           0
#
# [3500 rows x 3 columns]
# k: 9
#      PPC correct PPC predict        MAE
# 0            0.8    0.821126  0.0211262
# 1         0.7143    0.821126   0.106826
# 2            0.7    0.749394  0.0493937
# 3              1           1          0
# 4         0.4528    0.449477   0.003323
# ...          ...         ...        ...
# 3495           1    0.940185   0.059815
# 3496           1           1          0
# 3497           1    0.940185   0.059815
# 3498           1           1          0
# 3499         0.5         0.5          0
#
# [3500 rows x 3 columns]
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.083949   0.083949
# Mean Sqr Error      0.0210111  0.0210111
# Mean Sqr Log Error  0.0095557  0.0095557
# Mean Median Error   0.0319051  0.0319051
# R2 Score             0.761508   0.761508
# -----< COM ESCALONAMENTO >-----
# Seed                         0        Mean
# Error Metrics
# Mean Abs Error       0.0837668   0.0837668
# Mean Sqr Error       0.0209477   0.0209477
# Mean Sqr Log Error  0.00954181  0.00954181
# Mean Median Error    0.0315224   0.0315224
# R2 Score              0.762548    0.762548

# %%
evaluate_random_forest([
    'EdgeCoverage'
])

# %%
evaluate_random_forest([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1', 'EdgeCoverage'
])

# %% [markdown]
# ### Sem EC

# %%
feature_importance(RandomForestRegressor(), prev=metrics_without_ec)
# Out:
# -----< SEM ESCALONAMENTO >-----
# -----< COM ESCALONAMENTO >-----
# CountPath             0.411593
# CountLineCode         0.064945
# CountStmtExe.1        0.060277
# CountInput            0.059763
# CountOutput.1         0.050577
# CountOutput           0.042654
# CountStmtDecl.1       0.036732
# MaxNesting            0.036088
# CountLineCode.1       0.035685
# CountStmt.1           0.034427
# Cyclomatic            0.029345
# CountStmt             0.026061
# CountStmtDecl         0.024701
# Knots                 0.021195
# CountStmtExe          0.021088
# CyclomaticStrict      0.020053
# CyclomaticStrict.1    0.008161
# CountPathLog          0.005496
# CountPath.1           0.005300
# Cyclomatic.1          0.004434
# CountPathLog.1        0.001425
# Name: mean, dtype: float64

# %%
evaluate_random_forest([
    'CountStmtExe.1',
    'MaxNesting',
    'CountPath',
    'CountOutput.1'
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.180278   0.180278
# Mean Sqr Error      0.0595919  0.0595919
# Mean Sqr Log Error  0.0244451  0.0244451
# Mean Median Error    0.152176   0.152176
# R2 Score             0.302792   0.302792
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error        0.18015    0.18015
# Mean Sqr Error      0.0596361  0.0596361
# Mean Sqr Log Error  0.0244646  0.0244646
# Mean Median Error    0.151497   0.151497
# R2 Score             0.302505   0.302505

# %%
evaluate_random_forest(metrics_without_ec)
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.159688   0.159688
# Mean Sqr Error      0.0458667  0.0458667
# Mean Sqr Log Error  0.0187406  0.0187406
# Mean Median Error    0.141431   0.141431
# R2 Score             0.470645   0.470645
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.159676   0.159676
# Mean Sqr Error      0.0459336  0.0459336
# Mean Sqr Log Error  0.0187669  0.0187669
# Mean Median Error    0.141319   0.141319
# R2 Score             0.470072   0.470072

# %%
evaluate_random_forest([
    'CountStmtExe.1',
    'MaxNesting',
    'CountPath',
    'CountOutput.1',
    'Cyclomatic',
    'CountInput',
    'CountOutput',
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.163011   0.163011
# Mean Sqr Error      0.0492281  0.0492281
# Mean Sqr Log Error  0.0201276  0.0201276
# Mean Median Error    0.135709   0.135709
# R2 Score             0.431087   0.431087
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.162877   0.162877
# Mean Sqr Error       0.049147   0.049147
# Mean Sqr Log Error  0.0200893  0.0200893
# Mean Median Error     0.13694    0.13694
# R2 Score             0.431664   0.431664

# %%
evaluate_random_forest([
    #'CountPath',
    'CountPathLog',
    'CountStmtExe.1',
    'CountInput',
    'CountOutput',
    'CountOutput.1',
    'CountLineCode',
    'MaxNesting',
    'CountStmtDecl',
    'Cyclomatic',
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.163499   0.163499
# Mean Sqr Error      0.0483729  0.0483729
# Mean Sqr Log Error  0.0201434  0.0201434
# Mean Median Error    0.139661   0.139661
# R2 Score             0.445795   0.445795
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.163549   0.163549
# Mean Sqr Error      0.0484452  0.0484452
# Mean Sqr Log Error  0.0201811  0.0201811
# Mean Median Error    0.139987   0.139987
# R2 Score              0.44501    0.44501

# %%
evaluate_random_forest([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1'
])

# %%
evaluate_random_forest([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1', 
    'CountLineCode', 'MaxNesting'
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.162925   0.162925
# Mean Sqr Error      0.0482896  0.0482896
# Mean Sqr Log Error  0.0197962  0.0197962
# Mean Median Error    0.139389   0.139389
# R2 Score             0.442258   0.442258
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.162858   0.162858
# Mean Sqr Error      0.0482858  0.0482858
# Mean Sqr Log Error  0.0197985  0.0197985
# Mean Median Error    0.139144   0.139144
# R2 Score             0.442222   0.442222

# %%
evaluate_random_forest([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1'
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.163294   0.163294
# Mean Sqr Error      0.0495246  0.0495246
# Mean Sqr Log Error  0.0202786  0.0202786
# Mean Median Error    0.131559   0.131559
# R2 Score             0.429329   0.429329
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.163111   0.163111
# Mean Sqr Error       0.049426   0.049426
# Mean Sqr Log Error  0.0202405  0.0202405
# Mean Median Error    0.132787   0.132787
# R2 Score             0.430425   0.430425

# %% [markdown]
# ## Naive bayes
#
# **Aparentemente, não é compatível com variavel dependente como float**

# %%
def evaluate_nb(metrics, tot_seeds=0):
    seeds = [i for i in range(tot_seeds+1)]
    seeds.append('Mean')
    error_noscaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_scaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_noscaled_metrics_table.columns.name = 'Seed'
    error_noscaled_metrics_table.index.name = 'Error Metrics'
    error_scaled_metrics_table.columns.name = 'Seed'
    error_scaled_metrics_table.index.name = 'Error Metrics'

    for i in range(0,tot_seeds+1):
        error_metrics = evaluate(metrics, GaussianNB(var_smoothing =0.00000000001), dataset)
        error_noscaled_metrics_table[i] = error_metrics['no_scaled']
        error_scaled_metrics_table[i] = error_metrics['scaled']

    estimator_metrics_to_dataframe(error_noscaled_metrics_table, error_noscaled_metrics_table)
    estimator_metrics_to_dataframe(error_scaled_metrics_table, error_scaled_metrics_table)
    
    print('-----< SEM ESCALONAMENTO >-----')
    display(error_noscaled_metrics_table)
    print('-----< COM ESCALONAMENTO >-----')
    display(error_scaled_metrics_table)

# %% [markdown]
# ### Com EC

# %%
evaluate([
    'EdgeCoverage'
], GaussianNB(var_smoothing=1e-5))
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        5.000e-02, 5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02, 5.900e-02,
#        5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02, 6.670e-02,
#        7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02, 8.510e-02,
#        8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02,
#        1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01,
#        1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01,
#        1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01,
#        2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01,
#        2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01,
#        2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01,
#        2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01,
#        2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01, 3.125e-01,
#        3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01, 3.333e-01,
#        3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01,
#        3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01, 3.864e-01,
#        3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01,
#        4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01, 4.375e-01,
#        4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01, 4.651e-01,
#        4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01,
#        5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01,
#        5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01,
#        5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.286e-01, 4.340e-01, 4.348e-01,
#        4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01, 6.111e-01,
#        6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01, 6.486e-01,
#        6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01, 6.875e-01,
#        6.977e-01, 7.000e-01, 7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01,
#        7.273e-01, 7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01,
#        8.000e-01, 8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01,
#        8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01,
#        8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01,
#        9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02,
#        5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02,
#        6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.770e-02,
#        1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01,
#        1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01,
#        1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01,
#        2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.254e-01,
#        2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01,
#        2.558e-01, 2.593e-01, 2.632e-01, 2.742e-01, 2.759e-01, 2.800e-01,
#        2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01,
#        3.125e-01, 3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01, 3.333e-01,
#        3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01,
#        3.667e-01, 3.750e-01, 3.774e-01, 3.864e-01, 3.951e-01, 3.953e-01,
#        4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01,
#        4.286e-01, 4.340e-01, 4.348e-01, 4.375e-01, 4.444e-01, 4.545e-01,
#        4.595e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01,
#        8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01,
#        9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.500e-03, 9.100e-03, 1.040e-02,
#        1.780e-02, 2.080e-02, 2.130e-02, 2.380e-02, 2.500e-02, 2.540e-02,
#        2.780e-02, 3.030e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.760e-02, 5.000e-02,
#        5.260e-02, 5.640e-02, 5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02,
#        9.770e-02, 1.000e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.538e-01, 1.549e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.947e-01, 2.000e-01,
#        2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01,
#        2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.667e-01, 2.759e-01,
#        2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01, 3.103e-01, 3.158e-01,
#        3.210e-01, 3.333e-01, 3.448e-01, 3.478e-01, 3.580e-01, 3.585e-01,
#        3.636e-01, 3.750e-01, 3.774e-01, 3.793e-01, 3.951e-01, 4.000e-01,
#        4.098e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01, 4.444e-01,
#        4.528e-01, 4.615e-01, 4.717e-01, 4.800e-01, 5.000e-01, 5.200e-01,
#        5.283e-01, 5.333e-01, 5.385e-01, 5.455e-01, 5.472e-01, 5.500e-01,
#        5.552e-01, 5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01,
#        5.862e-01, 6.000e-01, 6.087e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01,
#        7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01,
#        8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01,
#        8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01,
#        9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01,
#        1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.0083, 0.0156, 0.0159, 0.0233, 0.0238, 0.0294, 0.0306, 0.0313,
#        0.0423, 0.0455, 0.0469, 0.0476, 0.05  , 0.0526, 0.0556, 0.0583,
#        0.0612, 0.0625, 0.0769, 0.0781, 0.0816, 0.0833, 0.0909, 0.0938,
#        0.1   , 0.102 , 0.1111, 0.1176, 0.1224, 0.125 , 0.1429, 0.15  ,
#        0.1633, 0.1667, 0.1765, 0.1818, 0.2   , 0.2143, 0.2222, 0.225 ,
#        0.2273, 0.2353, 0.25  , 0.2558, 0.2564, 0.2593, 0.2632, 0.2667,
#        0.2742, 0.2791, 0.2857, 0.2941, 0.2963, 0.3   , 0.3125, 0.3158,
#        0.3243, 0.3256, 0.3273, 0.3333, 0.3448, 0.3455, 0.3529, 0.3585,
#        0.3636, 0.3667, 0.375 , 0.3793, 0.3864, 0.3953, 0.4   , 0.4054,
#        0.4063, 0.4167, 0.4211, 0.4286, 0.4375, 0.4444, 0.4528, 0.4545,
#        0.4595, 0.4615, 0.4651, 0.4762, 0.5   , 0.5082, 0.52  , 0.5238,
#        0.5357, 0.5405, 0.5455, 0.55  , 0.5556, 0.5714, 0.5758, 0.5789,
#        0.5833, 0.5862, 0.6   , 0.6111, 0.625 , 0.6364, 0.64  , 0.6667,
#        0.7   , 0.7059, 0.7143, 0.7222, 0.7273, 0.7333, 0.75  , 0.7727,
#        0.7778, 0.7857, 0.8   , 0.8182, 0.8214, 0.8333, 0.8462, 0.85  ,
#        0.8571, 0.8667, 0.875 , 0.8889, 0.9   , 0.9091, 0.9167, 0.9286,
#        0.9333, 1.    ]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01,
#        8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01,
#        9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
# ...
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        5.000e-02, 5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02, 5.900e-02,
#        5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02, 6.670e-02,
#        7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02, 8.510e-02,
#        8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02,
#        1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01,
#        1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01,
#        1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01,
#        2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01,
#        2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01,
#        2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01,
#        2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01,
#        2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01, 3.125e-01,
#        3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01, 3.333e-01,
#        3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01,
#        3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01, 3.864e-01,
#        3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01,
#        4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01, 4.375e-01,
#        4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01, 4.651e-01,
#        4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01,
#        5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01,
#        5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01,
#        5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02,
#        5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02,
#        8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.286e-01, 4.340e-01, 4.348e-01,
#        4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01, 6.111e-01,
#        6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01, 6.486e-01,
#        6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01, 6.875e-01,
#        6.977e-01, 7.000e-01, 7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01,
#        7.273e-01, 7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01,
#        8.000e-01, 8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01,
#        8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01,
#        8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01,
#        9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02,
#        5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02,
#        6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.770e-02,
#        1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01,
#        1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01,
#        1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01,
#        2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.254e-01,
#        2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01,
#        2.558e-01, 2.593e-01, 2.632e-01, 2.742e-01, 2.759e-01, 2.800e-01,
#        2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01,
#        3.125e-01, 3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01, 3.333e-01,
#        3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01,
#        3.667e-01, 3.750e-01, 3.774e-01, 3.864e-01, 3.951e-01, 3.953e-01,
#        4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01,
#        4.286e-01, 4.340e-01, 4.348e-01, 4.375e-01, 4.444e-01, 4.545e-01,
#        4.595e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01,
#        8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01,
#        9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.500e-03, 9.100e-03, 1.040e-02,
#        1.780e-02, 2.080e-02, 2.130e-02, 2.380e-02, 2.500e-02, 2.540e-02,
#        2.780e-02, 3.030e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.760e-02, 5.000e-02,
#        5.260e-02, 5.640e-02, 5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02,
#        9.770e-02, 1.000e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.538e-01, 1.549e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.947e-01, 2.000e-01,
#        2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01,
#        2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.667e-01, 2.759e-01,
#        2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01, 3.103e-01, 3.158e-01,
#        3.210e-01, 3.333e-01, 3.448e-01, 3.478e-01, 3.580e-01, 3.585e-01,
#        3.636e-01, 3.750e-01, 3.774e-01, 3.793e-01, 3.951e-01, 4.000e-01,
#        4.098e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01, 4.444e-01,
#        4.528e-01, 4.615e-01, 4.717e-01, 4.800e-01, 5.000e-01, 5.200e-01,
#        5.283e-01, 5.333e-01, 5.385e-01, 5.455e-01, 5.472e-01, 5.500e-01,
#        5.552e-01, 5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01,
#        5.862e-01, 6.000e-01, 6.087e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01,
#        7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01,
#        8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01,
#        8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01,
#        9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01,
#        1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.0083, 0.0156, 0.0159, 0.0233, 0.0238, 0.0294, 0.0306, 0.0313,
#        0.0423, 0.0455, 0.0469, 0.0476, 0.05  , 0.0526, 0.0556, 0.0583,
#        0.0612, 0.0625, 0.0769, 0.0781, 0.0816, 0.0833, 0.0909, 0.0938,
#        0.1   , 0.102 , 0.1111, 0.1176, 0.1224, 0.125 , 0.1429, 0.15  ,
#        0.1633, 0.1667, 0.1765, 0.1818, 0.2   , 0.2143, 0.2222, 0.225 ,
#        0.2273, 0.2353, 0.25  , 0.2558, 0.2564, 0.2593, 0.2632, 0.2667,
#        0.2742, 0.2791, 0.2857, 0.2941, 0.2963, 0.3   , 0.3125, 0.3158,
#        0.3243, 0.3256, 0.3273, 0.3333, 0.3448, 0.3455, 0.3529, 0.3585,
#        0.3636, 0.3667, 0.375 , 0.3793, 0.3864, 0.3953, 0.4   , 0.4054,
#        0.4063, 0.4167, 0.4211, 0.4286, 0.4375, 0.4444, 0.4528, 0.4545,
#        0.4595, 0.4615, 0.4651, 0.4762, 0.5   , 0.5082, 0.52  , 0.5238,
#        0.5357, 0.5405, 0.5455, 0.55  , 0.5556, 0.5714, 0.5758, 0.5789,
#        0.5833, 0.5862, 0.6   , 0.6111, 0.625 , 0.6364, 0.64  , 0.6667,
#        0.7   , 0.7059, 0.7143, 0.7222, 0.7273, 0.7333, 0.75  , 0.7727,
#        0.7778, 0.7857, 0.8   , 0.8182, 0.8214, 0.8333, 0.8462, 0.85  ,
#        0.8571, 0.8667, 0.875 , 0.8889, 0.9   , 0.9091, 0.9167, 0.9286,
#        0.9333, 1.    ]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
#                    no_scaled scaled
# Mean Abs Error           NaN    NaN
# Mean Sqr Error           NaN    NaN
# Mean Sqr Log Error       NaN    NaN
# Mean Median Error        NaN    NaN
# R2 Score                 NaN    NaN

# %%
evaluate_nb([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1', 'EdgeCoverage'
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.560e-02, 1.780e-02, 2.130e-02, 2.330e-02, 2.380e-02, 2.500e-02,
#        2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02, 3.060e-02, 3.130e-02,
#        3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02, 4.030e-02, 4.230e-02,
#        4.350e-02, 4.550e-02, 4.690e-02, 5.000e-02, 5.260e-02, 5.560e-02,
#        5.640e-02, 5.830e-02, 5.880e-02, 5.900e-02, 6.000e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02,
#        9.770e-02, 1.000e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.176e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01,
#        1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01,
#        2.123e-01, 2.124e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01,
#        2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01,
#        2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01,
#        2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01,
#        3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01,
#        3.256e-01, 3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01,
#        3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01,
#        3.774e-01, 3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01,
#        4.054e-01, 4.063e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01,
#        6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01,
#        6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01,
#        7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01,
#        7.727e-01, 7.778e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01,
#        8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01,
#        8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01,
#        9.057e-01, 9.091e-01, 9.167e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.700e-03, 6.100e-03,
#        6.900e-03, 8.300e-03, 8.500e-03, 9.100e-03, 1.040e-02, 1.560e-02,
#        1.590e-02, 2.080e-02, 2.130e-02, 2.330e-02, 2.380e-02, 2.500e-02,
#        2.540e-02, 2.940e-02, 3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02,
#        3.390e-02, 3.810e-02, 4.000e-02, 4.230e-02, 4.350e-02, 4.550e-02,
#        4.690e-02, 4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02,
#        5.830e-02, 5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02,
#        8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02,
#        9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01,
#        1.064e-01, 1.111e-01, 1.169e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.580e-01,
#        3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01,
#        3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01,
#        4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01,
#        4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01,
#        5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01,
#        5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01,
#        8.235e-01, 8.333e-01, 8.462e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.0023, 0.003 , 0.004 , 0.0047, 0.0061, 0.0069, 0.0079, 0.0083,
#        0.0085, 0.0091, 0.0104, 0.0156, 0.0159, 0.0178, 0.0208, 0.0213,
#        0.0233, 0.0238, 0.0254, 0.0278, 0.0294, 0.0313, 0.0339, 0.0381,
#        0.04  , 0.0403, 0.0423, 0.0435, 0.0455, 0.0469, 0.0476, 0.05  ,
#        0.0526, 0.0556, 0.0564, 0.0583, 0.0588, 0.059 , 0.0591, 0.06  ,
#        0.0612, 0.0617, 0.0625, 0.0667, 0.0714, 0.0769, 0.0781, 0.0816,
#        0.0833, 0.0851, 0.0864, 0.0882, 0.0909, 0.0926, 0.0977, 0.1   ,
#        0.102 , 0.1062, 0.1064, 0.1111, 0.1169, 0.1176, 0.1224, 0.125 ,
#        0.1285, 0.1364, 0.1429, 0.15  , 0.1538, 0.1633, 0.1667, 0.1724,
#        0.1765, 0.177 , 0.1818, 0.1947, 0.2   , 0.2035, 0.2086, 0.2099,
#        0.2123, 0.2124, 0.2143, 0.2222, 0.225 , 0.2267, 0.2273, 0.2353,
#        0.24  , 0.25  , 0.2533, 0.2558, 0.2593, 0.2632, 0.2667, 0.2742,
#        0.2759, 0.2791, 0.2857, 0.2871, 0.2941, 0.2963, 0.3   , 0.3103,
#        0.3125, 0.3158, 0.321 , 0.3243, 0.3256, 0.3273, 0.3333, 0.3448,
#        0.3455, 0.3478, 0.3529, 0.358 , 0.3585, 0.3636, 0.3667, 0.375 ,
#        0.3774, 0.3793, 0.3864, 0.3951, 0.3953, 0.4   , 0.4054, 0.4063,
#        0.4098, 0.4167, 0.4211, 0.4286, 0.434 , 0.4348, 0.4375, 0.4444,
#        0.4528, 0.4545, 0.4595, 0.4615, 0.4651, 0.4717, 0.4762, 0.5   ,
#        0.5082, 0.52  , 0.5238, 0.5283, 0.5333, 0.5357, 0.5385, 0.5405,
#        0.5455, 0.5472, 0.55  , 0.5552, 0.5556, 0.5714, 0.5758, 0.5789,
#        0.5833, 0.5862, 0.6   , 0.6087, 0.6111, 0.6154, 0.6216, 0.625 ,
#        0.6364, 0.64  , 0.6486, 0.6512, 0.6604, 0.6667, 0.6744, 0.6757,
#        0.6875, 0.6977, 0.7   , 0.7059, 0.7143, 0.717 , 0.7209, 0.7222,
#        0.7273, 0.7333, 0.75  , 0.7727, 0.7778, 0.7857, 0.7925, 0.8   ,
#        0.8182, 0.8214, 0.8235, 0.8333, 0.8462, 0.85  , 0.8571, 0.8667,
#        0.875 , 0.88  , 0.8889, 0.8966, 0.9   , 0.9057, 0.9091, 0.9167,
#        0.9286, 0.9333, 0.9375, 1.    ]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03, 1.040e-02,
#        1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02,
#        3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02,
#        4.030e-02, 4.230e-02, 4.350e-02, 4.690e-02, 4.760e-02, 5.000e-02,
#        5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02, 5.900e-02, 5.910e-02,
#        6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02,
#        7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02,
#        8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01,
#        1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01, 1.176e-01,
#        1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.770e-01,
#        1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01,
#        2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01,
#        2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01,
#        2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01,
#        2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01, 2.941e-01, 2.963e-01,
#        3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01,
#        3.256e-01, 3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01,
#        3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01,
#        3.774e-01, 3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01,
#        4.054e-01, 4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01,
#        4.340e-01, 4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01,
#        4.595e-01, 4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01,
#        5.000e-01, 5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.357e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.214e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 3.030e-02, 3.060e-02,
#        3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02, 4.030e-02, 4.230e-02,
#        4.350e-02, 4.550e-02, 4.760e-02, 5.260e-02, 5.560e-02, 5.640e-02,
#        5.830e-02, 5.880e-02, 5.900e-02, 5.910e-02, 6.120e-02, 6.250e-02,
#        6.670e-02, 7.690e-02, 8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02,
#        8.820e-02, 9.090e-02, 9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01,
#        1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01,
#        1.250e-01, 1.285e-01, 1.429e-01, 1.549e-01, 1.633e-01, 1.667e-01,
#        1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01,
#        2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01,
#        2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01,
#        2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01, 2.800e-01,
#        2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.125e-01, 3.158e-01,
#        3.210e-01, 3.256e-01, 3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01,
#        3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01,
#        3.750e-01, 3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.800e-01, 5.000e-01, 5.200e-01, 5.283e-01,
#        5.333e-01, 5.385e-01, 5.455e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01,
#        6.111e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.486e-01, 6.512e-01,
#        6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01,
#        7.000e-01, 7.059e-01, 7.143e-01, 7.209e-01, 7.222e-01, 7.273e-01,
#        7.333e-01, 7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01,
#        8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.889e-01, 9.000e-01,
#        9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 4.000e-03, 6.100e-03, 7.900e-03, 8.300e-03,
#        8.500e-03, 9.100e-03, 1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02,
#        2.080e-02, 2.130e-02, 2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02,
#        2.780e-02, 2.940e-02, 3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02,
#        3.390e-02, 3.810e-02, 4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02,
#        4.550e-02, 4.690e-02, 4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02,
#        5.640e-02, 5.830e-02, 5.880e-02, 5.910e-02, 6.000e-02, 6.120e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02,
#        8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02,
#        9.260e-02, 9.380e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.364e-01,
#        1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01,
#        1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01,
#        2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01,
#        2.222e-01, 2.254e-01, 2.353e-01, 2.500e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.273e-01, 3.333e-01,
#        3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01,
#        3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01, 3.951e-01,
#        3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01, 4.167e-01,
#        4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01, 4.375e-01, 4.444e-01,
#        4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01, 4.717e-01, 4.762e-01,
#        4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01,
#        5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01,
#        5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01, 5.789e-01, 5.833e-01,
#        5.862e-01, 6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.143e-01, 7.170e-01, 7.209e-01,
#        7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01, 7.778e-01,
#        7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 9.100e-03, 1.040e-02,
#        1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.780e-02, 2.940e-02, 3.030e-02, 3.060e-02,
#        3.130e-02, 3.230e-02, 4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02,
#        4.550e-02, 4.690e-02, 4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02,
#        5.640e-02, 5.830e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02,
#        8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01,
#        8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01,
#        9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01,
#        9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.830e-02, 5.880e-02,
#        5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02,
#        6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02,
#        9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.111e-01, 1.176e-01,
#        1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.765e-01,
#        1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01,
#        2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.250e-01,
#        2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.742e-01, 2.759e-01,
#        2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01,
#        3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01,
#        3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01,
#        3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01,
#        4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01,
#        4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01,
#        6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01,
#        6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01,
#        7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01,
#        7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01,
#        8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01,
#        8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01,
#        9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01,
#        9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02,
#        3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02,
#        4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02, 4.760e-02,
#        5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02,
#        5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02,
#        6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02,
#        8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01,
#        1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01, 1.176e-01,
#        1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.765e-01,
#        1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01,
#        2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.250e-01,
#        2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01,
#        2.742e-01, 2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01,
#        2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01,
#        3.243e-01, 3.256e-01, 3.333e-01, 3.478e-01, 3.529e-01, 3.585e-01,
#        3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.864e-01, 3.953e-01,
#        4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01, 4.167e-01, 4.286e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.595e-01, 4.651e-01,
#        4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01, 5.238e-01,
#        5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01,
#        5.500e-01, 5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 6.000e-01,
#        6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01,
#        6.400e-01, 6.486e-01, 6.667e-01, 6.757e-01, 6.875e-01, 7.000e-01,
#        7.059e-01, 7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01,
#        7.500e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01,
#        8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01,
#        8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01,
#        9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01,
#        9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.500e-03, 9.100e-03, 1.040e-02,
#        1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02,
#        3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02,
#        4.030e-02, 4.230e-02, 4.550e-02, 4.690e-02, 4.760e-02, 5.000e-02,
#        5.260e-02, 5.560e-02, 5.640e-02, 5.880e-02, 5.900e-02, 5.910e-02,
#        6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02,
#        7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02,
#        8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01,
#        1.020e-01, 1.064e-01, 1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01,
#        1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01,
#        1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.765e-01, 1.818e-01,
#        2.000e-01, 2.086e-01, 2.099e-01, 2.143e-01, 2.222e-01, 2.250e-01,
#        2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01,
#        2.742e-01, 2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01,
#        2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01,
#        3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01, 3.333e-01, 3.448e-01,
#        3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01,
#        3.750e-01, 3.774e-01, 3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01,
#        4.000e-01, 4.054e-01, 4.098e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01, 4.651e-01,
#        4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01,
#        5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01,
#        5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01,
#        5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01, 6.486e-01,
#        6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01, 6.875e-01,
#        6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01, 7.222e-01,
#        7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01,
#        7.925e-01, 8.000e-01, 8.182e-01, 8.235e-01, 8.333e-01, 8.462e-01,
#        8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01,
#        8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01,
#        9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.560e-02, 1.780e-02, 2.130e-02, 2.330e-02, 2.380e-02, 2.500e-02,
#        2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02, 3.060e-02, 3.130e-02,
#        3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02, 4.030e-02, 4.230e-02,
#        4.350e-02, 4.550e-02, 4.690e-02, 5.000e-02, 5.260e-02, 5.560e-02,
#        5.640e-02, 5.830e-02, 5.880e-02, 5.900e-02, 6.000e-02, 6.170e-02,
#        6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02,
#        9.770e-02, 1.000e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01,
#        1.176e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01,
#        1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01,
#        2.123e-01, 2.124e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01,
#        2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01,
#        2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01,
#        2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01,
#        3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01,
#        3.256e-01, 3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01,
#        3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01,
#        3.774e-01, 3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01,
#        4.054e-01, 4.063e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01,
#        6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01,
#        6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01,
#        7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01,
#        7.727e-01, 7.778e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01,
#        8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01,
#        8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01,
#        9.057e-01, 9.091e-01, 9.167e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.700e-03, 6.100e-03,
#        6.900e-03, 8.300e-03, 8.500e-03, 9.100e-03, 1.040e-02, 1.560e-02,
#        1.590e-02, 2.080e-02, 2.130e-02, 2.330e-02, 2.380e-02, 2.500e-02,
#        2.540e-02, 2.940e-02, 3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02,
#        3.390e-02, 3.810e-02, 4.000e-02, 4.230e-02, 4.350e-02, 4.550e-02,
#        4.690e-02, 4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02,
#        5.830e-02, 5.880e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02,
#        8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02,
#        9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01,
#        1.064e-01, 1.111e-01, 1.169e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.580e-01,
#        3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01,
#        3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01,
#        4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01,
#        4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01,
#        5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01,
#        5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01,
#        6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01,
#        6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01,
#        7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01,
#        7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01,
#        8.235e-01, 8.333e-01, 8.462e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([0.0023, 0.003 , 0.004 , 0.0047, 0.0061, 0.0069, 0.0079, 0.0083,
#        0.0085, 0.0091, 0.0104, 0.0156, 0.0159, 0.0178, 0.0208, 0.0213,
#        0.0233, 0.0238, 0.0254, 0.0278, 0.0294, 0.0313, 0.0339, 0.0381,
#        0.04  , 0.0403, 0.0423, 0.0435, 0.0455, 0.0469, 0.0476, 0.05  ,
#        0.0526, 0.0556, 0.0564, 0.0583, 0.0588, 0.059 , 0.0591, 0.06  ,
#        0.0612, 0.0617, 0.0625, 0.0667, 0.0714, 0.0769, 0.0781, 0.0816,
#        0.0833, 0.0851, 0.0864, 0.0882, 0.0909, 0.0926, 0.0977, 0.1   ,
#        0.102 , 0.1062, 0.1064, 0.1111, 0.1169, 0.1176, 0.1224, 0.125 ,
#        0.1285, 0.1364, 0.1429, 0.15  , 0.1538, 0.1633, 0.1667, 0.1724,
#        0.1765, 0.177 , 0.1818, 0.1947, 0.2   , 0.2035, 0.2086, 0.2099,
#        0.2123, 0.2124, 0.2143, 0.2222, 0.225 , 0.2267, 0.2273, 0.2353,
#        0.24  , 0.25  , 0.2533, 0.2558, 0.2593, 0.2632, 0.2667, 0.2742,
#        0.2759, 0.2791, 0.2857, 0.2871, 0.2941, 0.2963, 0.3   , 0.3103,
#        0.3125, 0.3158, 0.321 , 0.3243, 0.3256, 0.3273, 0.3333, 0.3448,
#        0.3455, 0.3478, 0.3529, 0.358 , 0.3585, 0.3636, 0.3667, 0.375 ,
#        0.3774, 0.3793, 0.3864, 0.3951, 0.3953, 0.4   , 0.4054, 0.4063,
#        0.4098, 0.4167, 0.4211, 0.4286, 0.434 , 0.4348, 0.4375, 0.4444,
#        0.4528, 0.4545, 0.4595, 0.4615, 0.4651, 0.4717, 0.4762, 0.5   ,
#        0.5082, 0.52  , 0.5238, 0.5283, 0.5333, 0.5357, 0.5385, 0.5405,
#        0.5455, 0.5472, 0.55  , 0.5552, 0.5556, 0.5714, 0.5758, 0.5789,
#        0.5833, 0.5862, 0.6   , 0.6087, 0.6111, 0.6154, 0.6216, 0.625 ,
#        0.6364, 0.64  , 0.6486, 0.6512, 0.6604, 0.6667, 0.6744, 0.6757,
#        0.6875, 0.6977, 0.7   , 0.7059, 0.7143, 0.717 , 0.7209, 0.7222,
#        0.7273, 0.7333, 0.75  , 0.7727, 0.7778, 0.7857, 0.7925, 0.8   ,
#        0.8182, 0.8214, 0.8235, 0.8333, 0.8462, 0.85  , 0.8571, 0.8667,
#        0.875 , 0.88  , 0.8889, 0.8966, 0.9   , 0.9057, 0.9091, 0.9167,
#        0.9286, 0.9333, 0.9375, 1.    ]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
# ...
#        6.875e-01, 6.977e-01, 7.000e-01, 7.143e-01, 7.170e-01, 7.209e-01,
#        7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01, 7.778e-01,
#        7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01, 8.214e-01, 8.235e-01,
#        8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01,
#        8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01,
#        9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 9.100e-03, 1.040e-02,
#        1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.780e-02, 2.940e-02, 3.030e-02, 3.060e-02,
#        3.130e-02, 3.230e-02, 4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02,
#        4.550e-02, 4.690e-02, 4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02,
#        5.640e-02, 5.830e-02, 5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02,
#        6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02,
#        8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02, 9.090e-02, 9.260e-02,
#        9.380e-02, 9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.064e-01,
#        1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01, 1.250e-01, 1.285e-01,
#        1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01, 1.549e-01, 1.633e-01,
#        1.667e-01, 1.724e-01, 1.765e-01, 1.770e-01, 1.818e-01, 1.947e-01,
#        2.000e-01, 2.035e-01, 2.086e-01, 2.099e-01, 2.123e-01, 2.124e-01,
#        2.143e-01, 2.222e-01, 2.250e-01, 2.254e-01, 2.267e-01, 2.273e-01,
#        2.353e-01, 2.400e-01, 2.500e-01, 2.533e-01, 2.558e-01, 2.564e-01,
#        2.593e-01, 2.632e-01, 2.667e-01, 2.742e-01, 2.759e-01, 2.791e-01,
#        2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 2.963e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.158e-01, 3.210e-01, 3.243e-01, 3.256e-01,
#        3.273e-01, 3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01,
#        3.580e-01, 3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01,
#        3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01,
#        4.063e-01, 4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01,
#        4.615e-01, 4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01,
#        5.082e-01, 5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01,
#        5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01,
#        5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01,
#        6.000e-01, 6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01,
#        6.364e-01, 6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01,
#        6.744e-01, 6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01,
#        7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01,
#        7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01,
#        8.182e-01, 8.214e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01,
#        8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01,
#        9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01,
#        9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02,
#        2.330e-02, 2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02,
#        3.030e-02, 3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02,
#        4.000e-02, 4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02,
#        4.760e-02, 5.000e-02, 5.260e-02, 5.560e-02, 5.830e-02, 5.880e-02,
#        5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02,
#        6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02,
#        8.510e-02, 8.640e-02, 8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02,
#        9.770e-02, 1.000e-01, 1.020e-01, 1.062e-01, 1.111e-01, 1.176e-01,
#        1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.765e-01,
#        1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01,
#        2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.250e-01,
#        2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.742e-01, 2.759e-01,
#        2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01, 2.941e-01, 3.000e-01,
#        3.103e-01, 3.125e-01, 3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01,
#        3.333e-01, 3.448e-01, 3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01,
#        3.585e-01, 3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.793e-01,
#        3.864e-01, 3.951e-01, 3.953e-01, 4.000e-01, 4.054e-01, 4.063e-01,
#        4.098e-01, 4.167e-01, 4.211e-01, 4.286e-01, 4.340e-01, 4.348e-01,
#        4.375e-01, 4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01,
#        4.651e-01, 4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01,
#        5.200e-01, 5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01,
#        5.405e-01, 5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01,
#        5.714e-01, 5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01,
#        6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01,
#        6.400e-01, 6.486e-01, 6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01,
#        6.757e-01, 6.875e-01, 6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01,
#        7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01, 7.333e-01, 7.500e-01,
#        7.727e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01,
#        8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01,
#        8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01,
#        9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01,
#        9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.300e-03, 8.500e-03, 9.100e-03,
#        1.040e-02, 1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02,
#        3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02,
#        4.030e-02, 4.230e-02, 4.350e-02, 4.550e-02, 4.690e-02, 4.760e-02,
#        5.000e-02, 5.260e-02, 5.560e-02, 5.640e-02, 5.830e-02, 5.880e-02,
#        5.900e-02, 5.910e-02, 6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02,
#        6.670e-02, 7.140e-02, 7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02,
#        8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01,
#        1.020e-01, 1.062e-01, 1.064e-01, 1.111e-01, 1.169e-01, 1.176e-01,
#        1.224e-01, 1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01,
#        1.538e-01, 1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.765e-01,
#        1.770e-01, 1.818e-01, 1.947e-01, 2.000e-01, 2.035e-01, 2.086e-01,
#        2.099e-01, 2.123e-01, 2.124e-01, 2.143e-01, 2.222e-01, 2.250e-01,
#        2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01,
#        2.742e-01, 2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01,
#        2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01,
#        3.243e-01, 3.256e-01, 3.333e-01, 3.478e-01, 3.529e-01, 3.585e-01,
#        3.636e-01, 3.667e-01, 3.750e-01, 3.774e-01, 3.864e-01, 3.953e-01,
#        4.000e-01, 4.054e-01, 4.063e-01, 4.098e-01, 4.167e-01, 4.286e-01,
#        4.348e-01, 4.375e-01, 4.444e-01, 4.528e-01, 4.595e-01, 4.651e-01,
#        4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01, 5.238e-01,
#        5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01, 5.455e-01, 5.472e-01,
#        5.500e-01, 5.556e-01, 5.714e-01, 5.758e-01, 5.789e-01, 6.000e-01,
#        6.087e-01, 6.111e-01, 6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01,
#        6.400e-01, 6.486e-01, 6.667e-01, 6.757e-01, 6.875e-01, 7.000e-01,
#        7.059e-01, 7.143e-01, 7.170e-01, 7.209e-01, 7.222e-01, 7.273e-01,
#        7.500e-01, 7.778e-01, 7.857e-01, 7.925e-01, 8.000e-01, 8.182e-01,
#        8.214e-01, 8.235e-01, 8.333e-01, 8.462e-01, 8.500e-01, 8.571e-01,
#        8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01, 8.889e-01, 8.966e-01,
#        9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01, 9.286e-01, 9.333e-01,
#        9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 209, in fit
#     return self._partial_fit(X, y, np.unique(y), _refit=True,
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\naive_bayes.py", line 374, in _partial_fit
#     if _check_partial_fit_first_call(self, classes):
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 339, in _check_partial_fit_first_call
#     clf.classes_ = unique_labels(classes)
#   File "C:\ProgramData\Miniconda3\lib\site-packages\sklearn\utils\multiclass.py", line 98, in unique_labels
#     raise ValueError("Unknown label type: %s" % repr(ys))
# ValueError: Unknown label type: (array([9.000e-04, 1.800e-03, 2.300e-03, 3.000e-03, 4.000e-03, 4.700e-03,
#        6.100e-03, 6.900e-03, 7.900e-03, 8.500e-03, 9.100e-03, 1.040e-02,
#        1.560e-02, 1.590e-02, 1.780e-02, 2.080e-02, 2.130e-02, 2.330e-02,
#        2.380e-02, 2.500e-02, 2.540e-02, 2.780e-02, 2.940e-02, 3.030e-02,
#        3.060e-02, 3.130e-02, 3.230e-02, 3.390e-02, 3.810e-02, 4.000e-02,
#        4.030e-02, 4.230e-02, 4.550e-02, 4.690e-02, 4.760e-02, 5.000e-02,
#        5.260e-02, 5.560e-02, 5.640e-02, 5.880e-02, 5.900e-02, 5.910e-02,
#        6.000e-02, 6.120e-02, 6.170e-02, 6.250e-02, 6.670e-02, 7.140e-02,
#        7.690e-02, 7.810e-02, 8.160e-02, 8.330e-02, 8.510e-02, 8.640e-02,
#        8.820e-02, 9.090e-02, 9.260e-02, 9.380e-02, 9.770e-02, 1.000e-01,
#        1.020e-01, 1.064e-01, 1.111e-01, 1.169e-01, 1.176e-01, 1.224e-01,
#        1.250e-01, 1.285e-01, 1.364e-01, 1.429e-01, 1.500e-01, 1.538e-01,
#        1.549e-01, 1.633e-01, 1.667e-01, 1.724e-01, 1.765e-01, 1.818e-01,
#        2.000e-01, 2.086e-01, 2.099e-01, 2.143e-01, 2.222e-01, 2.250e-01,
#        2.254e-01, 2.267e-01, 2.273e-01, 2.353e-01, 2.400e-01, 2.500e-01,
#        2.533e-01, 2.558e-01, 2.564e-01, 2.593e-01, 2.632e-01, 2.667e-01,
#        2.742e-01, 2.759e-01, 2.791e-01, 2.800e-01, 2.857e-01, 2.871e-01,
#        2.941e-01, 2.963e-01, 3.000e-01, 3.103e-01, 3.125e-01, 3.158e-01,
#        3.210e-01, 3.243e-01, 3.256e-01, 3.273e-01, 3.333e-01, 3.448e-01,
#        3.455e-01, 3.478e-01, 3.529e-01, 3.580e-01, 3.585e-01, 3.636e-01,
#        3.750e-01, 3.774e-01, 3.793e-01, 3.864e-01, 3.951e-01, 3.953e-01,
#        4.000e-01, 4.054e-01, 4.098e-01, 4.211e-01, 4.286e-01, 4.340e-01,
#        4.444e-01, 4.528e-01, 4.545e-01, 4.595e-01, 4.615e-01, 4.651e-01,
#        4.717e-01, 4.762e-01, 4.800e-01, 5.000e-01, 5.082e-01, 5.200e-01,
#        5.238e-01, 5.283e-01, 5.333e-01, 5.357e-01, 5.385e-01, 5.405e-01,
#        5.455e-01, 5.472e-01, 5.500e-01, 5.552e-01, 5.556e-01, 5.714e-01,
#        5.758e-01, 5.789e-01, 5.833e-01, 5.862e-01, 6.000e-01, 6.087e-01,
#        6.154e-01, 6.216e-01, 6.250e-01, 6.364e-01, 6.400e-01, 6.486e-01,
#        6.512e-01, 6.604e-01, 6.667e-01, 6.744e-01, 6.757e-01, 6.875e-01,
#        6.977e-01, 7.000e-01, 7.059e-01, 7.143e-01, 7.170e-01, 7.222e-01,
#        7.273e-01, 7.333e-01, 7.500e-01, 7.727e-01, 7.778e-01, 7.857e-01,
#        7.925e-01, 8.000e-01, 8.182e-01, 8.235e-01, 8.333e-01, 8.462e-01,
#        8.500e-01, 8.571e-01, 8.667e-01, 8.750e-01, 8.788e-01, 8.800e-01,
#        8.889e-01, 8.966e-01, 9.000e-01, 9.057e-01, 9.091e-01, 9.167e-01,
#        9.286e-01, 9.333e-01, 9.375e-01, 1.000e+00]),)
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# Seed                  0 Mean
# Error Metrics
# Mean Abs Error      NaN  NaN
# Mean Sqr Error      NaN  NaN
# Mean Sqr Log Error  NaN  NaN
# Mean Median Error   NaN  NaN
# R2 Score            NaN  NaN
# -----< COM ESCALONAMENTO >-----
# Seed                  0 Mean
# Error Metrics
# Mean Abs Error      NaN  NaN
# Mean Sqr Error      NaN  NaN
# Mean Sqr Log Error  NaN  NaN
# Mean Median Error   NaN  NaN
# R2 Score            NaN  NaN

# %% [markdown]
# ### Sem EC

# %% [markdown]
# ## KNeighborsRegressor

# %%
def evaluate_knr(metrics, tot_seeds=0, display_feature_importance=False):
    seeds = [i for i in range(tot_seeds+1)]
    seeds.append('Mean')
    error_noscaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_scaled_metrics_table = pd.DataFrame(
        index=['Mean Abs Error', 'Mean Sqr Error', 'Mean Sqr Log Error', 'Mean Median Error', 'R2 Score'],
        columns=seeds
    )
    error_noscaled_metrics_table.columns.name = 'Seed'
    error_noscaled_metrics_table.index.name = 'Error Metrics'
    error_scaled_metrics_table.columns.name = 'Seed'
    error_scaled_metrics_table.index.name = 'Error Metrics'

    for i in range(0,tot_seeds+1):
        error_metrics = evaluate(metrics, KNeighborsRegressor(), dataset, display_feature_importance=display_feature_importance)
        error_noscaled_metrics_table[i] = error_metrics['no_scaled']
        error_scaled_metrics_table[i] = error_metrics['scaled']

    estimator_metrics_to_dataframe(error_noscaled_metrics_table, error_noscaled_metrics_table)
    estimator_metrics_to_dataframe(error_scaled_metrics_table, error_scaled_metrics_table)
    
    print('-----< SEM ESCALONAMENTO >-----')
    display(error_noscaled_metrics_table)
    print('-----< COM ESCALONAMENTO >-----')
    display(error_scaled_metrics_table)

# %%
evaluate_knr(previsores, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 12        EdgeCoverage    0.0975858
# 6         CountPathLog    0.0175717
# 11          MaxNesting   0.00976337
# 0           CountInput   0.00829443
# 2          CountOutput   0.00309729
# 4        CountStmtDecl   0.00231773
# 16     CountStmtDecl.1   0.00181158
# 10               Knots    0.0012079
# 14       CountOutput.1   0.00120462
# 7         CountStmtExe  0.000752799
# 3            CountStmt  0.000438858
# 8           Cyclomatic  0.000372433
# 21  CyclomaticStrict.1  0.000370034
# 9     CyclomaticStrict  0.000339163
# 19      CountStmtExe.1  0.000305815
# 15         CountStmt.1   0.00030443
# 13     CountLineCode.1  0.000299881
# 20        Cyclomatic.1  0.000144435
# 1        CountLineCode  0.000115165
# 18      CountPathLog.1  0.000100736
# 5            CountPath  2.62989e-05
# 17         CountPath.1            0
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.182222   0.182222
# Mean Sqr Error      0.0614443  0.0614443
# Mean Sqr Log Error  0.0248497  0.0248497
# Mean Median Error    0.140004   0.140004
# R2 Score             0.300657   0.300657
# -----< COM ESCALONAMENTO >-----
# Seed                         0        Mean
# Error Metrics
# Mean Abs Error       0.0785483   0.0785483
# Mean Sqr Error       0.0187728   0.0187728
# Mean Sqr Log Error  0.00868983  0.00868983
# Mean Median Error     0.026542    0.026542
# R2 Score              0.791203    0.791203

# %%
evaluate_knr(metrics_without_ec, display_feature_importance=True)
# Out:
# <ipython-input-1419-8e77325cb46c>:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fi_scaled_table['Mean'][i] = fi_scaled_table.iloc[i,:-1].mean()
#                Metrics   Importance
# 6         CountPathLog    0.0437458
# 11          MaxNesting     0.040628
# 0           CountInput    0.0154252
# 15     CountStmtDecl.1    0.0114706
# 13       CountOutput.1   0.00791757
# 2          CountOutput   0.00775028
# 4        CountStmtDecl   0.00638789
# 10               Knots   0.00542147
# 14         CountStmt.1   0.00387495
# 18      CountStmtExe.1   0.00372661
# 8           Cyclomatic   0.00366777
# 12     CountLineCode.1   0.00321035
# 7         CountStmtExe   0.00280044
# 20  CyclomaticStrict.1   0.00207955
# 9     CyclomaticStrict   0.00176659
# 19        Cyclomatic.1   0.00165249
# 17      CountPathLog.1   0.00131853
# 1        CountLineCode   0.00112264
# 3            CountStmt   0.00107698
# 5            CountPath  1.96027e-05
# 16         CountPath.1  6.26636e-06
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.185642   0.185642
# Mean Sqr Error      0.0631022  0.0631022
# Mean Sqr Log Error  0.0254331  0.0254331
# Mean Median Error    0.143775   0.143775
# R2 Score             0.281451   0.281451
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.172014   0.172014
# Mean Sqr Error      0.0587232  0.0587232
# Mean Sqr Log Error  0.0242548  0.0242548
# Mean Median Error     0.13352    0.13352
# R2 Score             0.323405   0.323405

# %% [markdown]
# ### Com EC

# %%
evaluate_knr([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1', 'EdgeCoverage'
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.193186   0.193186
# Mean Sqr Error      0.0659672  0.0659672
# Mean Sqr Log Error   0.026666   0.026666
# Mean Median Error     0.15652    0.15652
# R2 Score             0.244686   0.244686
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.109073   0.109073
# Mean Sqr Error      0.0284099  0.0284099
# Mean Sqr Log Error  0.0126339  0.0126339
# Mean Median Error    0.066592   0.066592
# R2 Score             0.679172   0.679172

# %% [markdown]
# ### Sem EC

# %%
evaluate_knr([
    'CountPath', 'CountStmtExe.1', 'CountInput', 'CountOutput', 'CountOutput.1'
])
# Out:
# -----< SEM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.204274   0.204274
# Mean Sqr Error      0.0709502  0.0709502
# Mean Sqr Log Error  0.0285269  0.0285269
# Mean Median Error     0.17017    0.17017
# R2 Score              0.18978    0.18978
# -----< COM ESCALONAMENTO >-----
# Seed                        0       Mean
# Error Metrics
# Mean Abs Error       0.244405   0.244405
# Mean Sqr Error      0.0965009  0.0965009
# Mean Sqr Log Error  0.0393374  0.0393374
# Mean Median Error    0.216909   0.216909
# R2 Score            0.0867962  0.0867962
